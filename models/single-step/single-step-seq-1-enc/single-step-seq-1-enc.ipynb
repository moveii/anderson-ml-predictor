# %%
import random
import math
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from dataclasses import dataclass

# %%
seed = 42

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed);

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device {device}')
# Out:
# Using device cuda

# %% [markdown]
# ### Prepare the data

# %%
class ImpurityDataset(Dataset):
    
    def __init__(self, dataframe, fixed_features, labels, feature_scaler=None, label_scaler=None, device=None):
        assert len(labels) % 2 == 0
        
        self.fixed_features = fixed_features
        self.labels = labels
        self.n_samples = len(dataframe)
        
        self.output_length = len(labels)
        self.input_length = len(fixed_features)
        self.sequence_length = 1
        
        df_features = dataframe[fixed_features]
        df_labels = dataframe[labels]

        if feature_scaler is not None and label_scaler is not None:
            xs = feature_scaler.transform(df_features.values)
            ys = label_scaler.transform(df_labels.values)
        else:
            xs = df_features.values
            ys = df_labels.values

        feature_data = np.zeros((self.n_samples, self.sequence_length, self.input_length))
        label_data = np.zeros((self.n_samples, self.sequence_length, self.output_length))
        
        for i in range(self.n_samples):
            xi = xs[i]
            yi = ys[i]
            
            feature_data[i, :, :] = xi
            label_data[i, :, :] = yi

        self.feature_data = torch.tensor(feature_data, dtype=torch.float).to(device)
        self.label_data = torch.tensor(label_data, dtype=torch.float).to(device)

    def __len__(self):
        return self.n_samples

    def __getitem__(self, idx):
        return self.feature_data[idx], self.label_data[idx]

# %%
def compute_scalers(dataframe, fixed_features, labels, test_size, random_state=None):
    train_df, _ = train_test_split(dataframe, test_size=test_size, random_state=random_state)
    df_features = train_df[fixed_features]
    df_labels = train_df[labels]
    
    feature_scaler = StandardScaler()
    feature_scaler.fit(df_features.values)
    
    label_scaler = StandardScaler()
    label_scaler.fit(df_labels.values)

    return feature_scaler, label_scaler

# %%
file_path = '../data/20230825_144318_10k_EVDoubExp-TExp-wmax5-sparse-hyb_with_perturbation.csv'

#fixed_features = ['beta', 'U', 'Eimp', 'E1', 'E2', 'E3', 'V1', 'V2', 'V3']

# original feature set
#fixed_features = ['beta', 'E1', 'E2', 'E3', 'V1', 'V2', 'V3']

fixed_features = ['beta', 'E1', 'E2', 'E3', 'V1', 'V2', 'V3', 'ReFso1', 'ImFso1', 'ReFso3', 'ImFso3', 'ReFso5', 'ImFso5', 'ReFso7', 'ImFso7', 'ReFso9', 'ImFso9', 'ReFso11', 'ImFso11', 'ReFso13', 'ImFso13', 'ReFso15', 'ImFso15', 'ReFso17', 'ImFso17', 'ReFso19', 'ImFso19', 'ReFso21', 'ImFso21', 'ReFso23', 'ImFso23', 'ReFso25', 'ImFso25', 'ReFso29', 'ImFso29', 'ReFso33', 'ImFso33', 'ReFso37', 'ImFso37', 'ReFso43', 'ImFso43', 'ReFso49', 'ImFso49', 'ReFso57', 'ImFso57', 'ReFso69', 'ImFso69', 'ReFso83', 'ImFso83', 'ReFso101', 'ImFso101', 'ReFso127', 'ImFso127', 'ReFso165', 'ImFso165', 'ReFso237', 'ImFso237', 'ReFso399', 'ImFso399', 'ReFso1207', 'ImFso1207']

labels = ['ReSf1', 'ImSf1', 'ReSf3', 'ImSf3', 'ReSf5', 'ImSf5', 'ReSf7', 'ImSf7', 'ReSf9', 'ImSf9', 'ReSf11', 'ImSf11', 'ReSf13', 'ImSf13', 'ReSf15', 'ImSf15', 'ReSf17', 'ImSf17', 'ReSf19', 'ImSf19', 'ReSf21', 'ImSf21', 'ReSf23', 'ImSf23', 'ReSf25', 'ImSf25', 'ReSf29', 'ImSf29', 'ReSf33', 'ImSf33', 'ReSf37', 'ImSf37', 'ReSf43', 'ImSf43', 'ReSf49', 'ImSf49', 'ReSf57', 'ImSf57', 'ReSf69', 'ImSf69', 'ReSf83', 'ImSf83', 'ReSf101', 'ImSf101', 'ReSf127', 'ImSf127', 'ReSf165', 'ImSf165', 'ReSf237', 'ImSf237', 'ReSf399', 'ImSf399', 'ReSf1207', 'ImSf1207']

df = pd.read_csv(file_path, skiprows=4) # we skip the first four lines, because they are just metadata
df = df[fixed_features + labels]

# remove one special row, looks very weird; ReSf1 = 2.377167465976437e-06
df = df[df['ReSf1'] >= 1e-05]

validation_size = 0.1 # 90% training, 10% for validation

use_scaling = True

if use_scaling:
    feature_scaler, label_scaler = compute_scalers(df, fixed_features, labels, validation_size, seed) # make sure we use the same seed, otherwise the two splits differ!
    dataset = ImpurityDataset(df, fixed_features, labels, feature_scaler, label_scaler, device=device)
else:
    dataset = ImpurityDataset(df, fixed_features, labels, device=device)

indices = list(range(len(dataset)))
train_indices, val_indices = train_test_split(indices, test_size=validation_size, random_state=seed)  # make sure we use the same seed, otherwise the two splits differ!

train_dataset = Subset(dataset, train_indices)
val_dataset = Subset(dataset, val_indices)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=True, num_workers=0)

# %%
dataset.__getitem__(0);

# %%
sorted(df['ReSf1'].abs())[:10];

# %% [markdown]
# ### Define the model

# %%
@dataclass
class ModelConfig:
    input_dim: int
    output_dim: int
    sequence_length: int
    
    d_model: int
    nhead: int
    num_layers: int
    dim_feedforward: int
    
    dropout: float
    activation: str
    bias: bool

class AutoregressiveTransformer(nn.Module):
    
    def __init__(self, config, device):
        super(AutoregressiveTransformer, self).__init__()

        self.config = config
        self.input_projection = nn.Linear(config.input_dim, config.d_model)
        
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=config.d_model, 
            nhead=config.nhead, 
            dim_feedforward=config.dim_feedforward, 
            dropout=config.dropout,
            activation=config.activation, 
            batch_first=True, 
            norm_first=True, 
            bias=config.bias
        )
        
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=config.num_layers)
        self.output_layer = nn.Linear(config.d_model, config.output_dim)
        
    def forward(self, x):        
        x = self.input_projection(x)
        output = self.transformer_encoder(x)
        output = self.output_layer(output)
        
        return output

# %% [markdown]
# ### Initialize the model

# %%
config = ModelConfig(
    input_dim = len(fixed_features),
    output_dim = len(labels),
    sequence_length = 1,
    
    d_model = 64,
    nhead = 2,
    num_layers = 2,
    dim_feedforward = 64 * 4,
    
    dropout = 0.2,
    activation = 'gelu',
    bias = True
)

model = AutoregressiveTransformer(config, device).to(device)
print(sum(p.numel() for p in model.parameters())/1e3, 'k parameters')
criterion = nn.MSELoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
# Out:
# 107.446 k parameters

# %%
def train(model, loader, optimizer, criterion, device):
    model.train()
    losses = []
    
    for inputs, targets in loader:
        
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, targets)
        
        loss.backward()
        optimizer.step()
        
        losses.append(loss.item())

    return np.average(losses)

# %%
def validate(model, loader, criterion, device):
    model.eval()
    losses = []
    
    with torch.no_grad():
        
        for inputs, targets in loader:
            
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            losses.append(loss.item())
            
    return np.average(losses)

# %%
def validate_mape(model, loader, device, use_scaling=use_scaling, epsilon=1e-8):
    model.eval()
    losses = []
    
    with torch.no_grad():
        
        for inputs, targets in loader:
            outputs = model(inputs)
            
            if use_scaling:
                outputs = torch.tensor(reverse_tranform_output(outputs, label_scaler))
                targets = torch.tensor(reverse_tranform_output(targets, label_scaler))
            
            ape = torch.abs((targets - outputs) / (targets + epsilon))
            mape = torch.mean(ape) * 100
            
            losses.append(mape.item())

    return np.average(losses)

# %%
def reverse_tranform_output(data, scaler):
    B, T, C = data.shape
    data = data.view(B, T*C)
    data = data.cpu().numpy()
    return scaler.inverse_transform(data)

# %%
validate_mape(model, val_loader, device, use_scaling=use_scaling)
# Out:
# 144.7717912197113

# %% [markdown]
# ### Train the model

# %%
num_epochs = 1000

# Initialize variables to store the lowest losses and corresponding epochs
lowest_train_loss = float('inf')
lowest_val_loss = float('inf')
best_train_epoch = -1
best_val_epoch = -1

for epoch in range(num_epochs):
    train(model, train_loader, optimizer, criterion, device)
    
    train_loss = validate(model, train_loader, criterion, device)
    val_loss = validate(model, val_loader, criterion, device)
    
    train_mape = validate_mape(model, train_loader, device, use_scaling=use_scaling)
    val_mape = validate_mape(model, val_loader, device, use_scaling=use_scaling)

    print(f"Epoch {(epoch+1):3d}: Train Loss: {train_loss:.6f}, Train MAPE: {train_mape:.3f}%, Val Loss: {val_loss:.6f}, Val MAPE: {val_mape:.3f}%")
    
    if train_mape < lowest_train_loss:
        lowest_train_loss = train_mape
        best_train_epoch = epoch + 1

    if val_mape < lowest_val_loss:
        lowest_val_loss = val_mape
        best_val_epoch = epoch + 1

print(f"\nLowest Train Loss: {lowest_train_loss:.6f} at Epoch {best_train_epoch}")
print(f"Lowest Val Loss: {lowest_val_loss:.6f} at Epoch {best_val_epoch}")
# Out:
# Epoch   1: Train Loss: 0.177164, Train MAPE: 27.308%, Val Loss: 0.179814, Val MAPE: 32.140%
# Epoch   2: Train Loss: 0.117193, Train MAPE: 21.202%, Val Loss: 0.118066, Val MAPE: 24.843%
# Epoch   3: Train Loss: 0.092693, Train MAPE: 18.664%, Val Loss: 0.094550, Val MAPE: 21.625%
# Epoch   4: Train Loss: 0.079170, Train MAPE: 17.205%, Val Loss: 0.082246, Val MAPE: 19.567%
# Epoch   5: Train Loss: 0.066922, Train MAPE: 15.727%, Val Loss: 0.077353, Val MAPE: 18.669%
# Epoch   6: Train Loss: 0.061451, Train MAPE: 14.931%, Val Loss: 0.065295, Val MAPE: 16.218%
# Epoch   7: Train Loss: 0.049913, Train MAPE: 14.108%, Val Loss: 0.056242, Val MAPE: 15.620%
# Epoch   8: Train Loss: 0.044516, Train MAPE: 12.600%, Val Loss: 0.051971, Val MAPE: 13.970%
# Epoch   9: Train Loss: 0.040889, Train MAPE: 11.461%, Val Loss: 0.047905, Val MAPE: 12.461%
# Epoch  10: Train Loss: 0.036797, Train MAPE: 11.171%, Val Loss: 0.045303, Val MAPE: 12.699%
# Epoch  11: Train Loss: 0.036468, Train MAPE: 10.937%, Val Loss: 0.046297, Val MAPE: 12.175%
# Epoch  12: Train Loss: 0.033574, Train MAPE: 10.375%, Val Loss: 0.043042, Val MAPE: 11.601%
# Epoch  13: Train Loss: 0.038421, Train MAPE: 10.032%, Val Loss: 0.048019, Val MAPE: 12.067%
# Epoch  14: Train Loss: 0.029410, Train MAPE: 10.013%, Val Loss: 0.040864, Val MAPE: 11.799%
# Epoch  15: Train Loss: 0.028252, Train MAPE: 10.337%, Val Loss: 0.038366, Val MAPE: 12.585%
# Epoch  16: Train Loss: 0.026003, Train MAPE: 9.829%, Val Loss: 0.038486, Val MAPE: 12.357%
# Epoch  17: Train Loss: 0.024927, Train MAPE: 9.479%, Val Loss: 0.037452, Val MAPE: 11.675%
# Epoch  18: Train Loss: 0.024669, Train MAPE: 7.826%, Val Loss: 0.036957, Val MAPE: 9.991%
# Epoch  19: Train Loss: 0.024814, Train MAPE: 8.315%, Val Loss: 0.034873, Val MAPE: 10.041%
# Epoch  20: Train Loss: 0.024667, Train MAPE: 7.615%, Val Loss: 0.036084, Val MAPE: 9.515%
# Epoch  21: Train Loss: 0.023143, Train MAPE: 7.097%, Val Loss: 0.035323, Val MAPE: 8.624%
# Epoch  22: Train Loss: 0.022837, Train MAPE: 7.019%, Val Loss: 0.033986, Val MAPE: 8.903%
# Epoch  23: Train Loss: 0.023025, Train MAPE: 6.973%, Val Loss: 0.033859, Val MAPE: 8.264%
# Epoch  24: Train Loss: 0.020223, Train MAPE: 6.815%, Val Loss: 0.032286, Val MAPE: 8.383%
# Epoch  25: Train Loss: 0.021421, Train MAPE: 6.807%, Val Loss: 0.034457, Val MAPE: 8.267%
# Epoch  26: Train Loss: 0.021134, Train MAPE: 6.245%, Val Loss: 0.033613, Val MAPE: 7.479%
# Epoch  27: Train Loss: 0.021767, Train MAPE: 6.711%, Val Loss: 0.030998, Val MAPE: 8.162%
# Epoch  28: Train Loss: 0.018956, Train MAPE: 6.234%, Val Loss: 0.029499, Val MAPE: 7.366%
# Epoch  29: Train Loss: 0.021670, Train MAPE: 6.227%, Val Loss: 0.032008, Val MAPE: 7.013%
# Epoch  30: Train Loss: 0.018185, Train MAPE: 6.067%, Val Loss: 0.029703, Val MAPE: 7.727%
# Epoch  31: Train Loss: 0.018147, Train MAPE: 5.862%, Val Loss: 0.030047, Val MAPE: 7.296%
# Epoch  32: Train Loss: 0.023768, Train MAPE: 5.847%, Val Loss: 0.033061, Val MAPE: 7.462%
# Epoch  33: Train Loss: 0.017819, Train MAPE: 5.851%, Val Loss: 0.029108, Val MAPE: 6.739%
# Epoch  34: Train Loss: 0.017117, Train MAPE: 5.619%, Val Loss: 0.028957, Val MAPE: 6.540%
# Epoch  35: Train Loss: 0.017960, Train MAPE: 5.584%, Val Loss: 0.028554, Val MAPE: 6.619%
# Epoch  36: Train Loss: 0.017191, Train MAPE: 5.580%, Val Loss: 0.028859, Val MAPE: 6.529%
# Epoch  37: Train Loss: 0.016961, Train MAPE: 5.896%, Val Loss: 0.029294, Val MAPE: 6.753%
# Epoch  38: Train Loss: 0.016410, Train MAPE: 6.113%, Val Loss: 0.027532, Val MAPE: 6.805%
# Epoch  39: Train Loss: 0.017029, Train MAPE: 5.815%, Val Loss: 0.027913, Val MAPE: 6.892%
# Epoch  40: Train Loss: 0.019354, Train MAPE: 5.162%, Val Loss: 0.030142, Val MAPE: 7.551%
# Epoch  41: Train Loss: 0.015431, Train MAPE: 5.304%, Val Loss: 0.026959, Val MAPE: 6.340%
# Epoch  42: Train Loss: 0.020412, Train MAPE: 6.491%, Val Loss: 0.028757, Val MAPE: 7.242%
# Epoch  43: Train Loss: 0.024335, Train MAPE: 5.357%, Val Loss: 0.032518, Val MAPE: 6.257%
# Epoch  44: Train Loss: 0.024133, Train MAPE: 6.250%, Val Loss: 0.031832, Val MAPE: 6.881%
# Epoch  45: Train Loss: 0.016408, Train MAPE: 5.120%, Val Loss: 0.026501, Val MAPE: 5.854%
# Epoch  46: Train Loss: 0.014829, Train MAPE: 5.006%, Val Loss: 0.025504, Val MAPE: 5.852%
# Epoch  47: Train Loss: 0.015591, Train MAPE: 5.304%, Val Loss: 0.027169, Val MAPE: 6.263%
# Epoch  48: Train Loss: 0.021142, Train MAPE: 4.927%, Val Loss: 0.030819, Val MAPE: 6.014%
# Epoch  49: Train Loss: 0.016083, Train MAPE: 5.462%, Val Loss: 0.027450, Val MAPE: 6.314%
# Epoch  50: Train Loss: 0.015438, Train MAPE: 5.282%, Val Loss: 0.025578, Val MAPE: 6.081%
# Epoch  51: Train Loss: 0.014578, Train MAPE: 4.993%, Val Loss: 0.024906, Val MAPE: 5.754%
# Epoch  52: Train Loss: 0.014204, Train MAPE: 4.817%, Val Loss: 0.025506, Val MAPE: 5.702%
# Epoch  53: Train Loss: 0.015000, Train MAPE: 4.535%, Val Loss: 0.024378, Val MAPE: 5.379%
# Epoch  54: Train Loss: 0.015793, Train MAPE: 5.474%, Val Loss: 0.024483, Val MAPE: 6.329%
# Epoch  55: Train Loss: 0.016365, Train MAPE: 4.542%, Val Loss: 0.027102, Val MAPE: 5.296%
# Epoch  56: Train Loss: 0.015873, Train MAPE: 5.343%, Val Loss: 0.025125, Val MAPE: 6.127%
# Epoch  57: Train Loss: 0.014130, Train MAPE: 4.713%, Val Loss: 0.023442, Val MAPE: 5.439%
# Epoch  58: Train Loss: 0.014196, Train MAPE: 5.240%, Val Loss: 0.024654, Val MAPE: 6.471%
# Epoch  59: Train Loss: 0.014148, Train MAPE: 4.887%, Val Loss: 0.068525, Val MAPE: 6.241%
# Epoch  60: Train Loss: 0.013380, Train MAPE: 4.292%, Val Loss: 0.024228, Val MAPE: 5.033%
# Epoch  61: Train Loss: 0.018632, Train MAPE: 5.105%, Val Loss: 0.025682, Val MAPE: 5.535%
# Epoch  62: Train Loss: 0.013114, Train MAPE: 4.059%, Val Loss: 0.022922, Val MAPE: 4.773%
# Epoch  63: Train Loss: 0.017946, Train MAPE: 4.212%, Val Loss: 0.028261, Val MAPE: 5.001%
# Epoch  64: Train Loss: 0.014139, Train MAPE: 5.027%, Val Loss: 0.023828, Val MAPE: 5.878%
# Epoch  65: Train Loss: 0.016499, Train MAPE: 4.311%, Val Loss: 0.025921, Val MAPE: 5.031%
# Epoch  66: Train Loss: 0.014368, Train MAPE: 4.362%, Val Loss: 0.024063, Val MAPE: 5.188%
# Epoch  67: Train Loss: 0.015001, Train MAPE: 4.866%, Val Loss: 0.024063, Val MAPE: 5.652%
# Epoch  68: Train Loss: 0.012156, Train MAPE: 4.172%, Val Loss: 0.021559, Val MAPE: 4.885%
# Epoch  69: Train Loss: 0.012882, Train MAPE: 4.456%, Val Loss: 0.022612, Val MAPE: 5.535%
# Epoch  70: Train Loss: 0.012473, Train MAPE: 4.454%, Val Loss: 0.022754, Val MAPE: 5.424%
# Epoch  71: Train Loss: 0.013872, Train MAPE: 4.795%, Val Loss: 0.022502, Val MAPE: 5.915%
# Epoch  72: Train Loss: 0.013915, Train MAPE: 4.879%, Val Loss: 0.023334, Val MAPE: 5.930%
# Epoch  73: Train Loss: 0.014242, Train MAPE: 4.539%, Val Loss: 0.061247, Val MAPE: 6.230%
# Epoch  74: Train Loss: 0.012194, Train MAPE: 4.265%, Val Loss: 0.021441, Val MAPE: 5.004%
# Epoch  75: Train Loss: 0.012246, Train MAPE: 4.510%, Val Loss: 0.020585, Val MAPE: 5.522%
# Epoch  76: Train Loss: 0.012495, Train MAPE: 4.265%, Val Loss: 0.021997, Val MAPE: 5.094%
# Epoch  77: Train Loss: 0.015559, Train MAPE: 4.728%, Val Loss: 0.025774, Val MAPE: 5.747%
# Epoch  78: Train Loss: 0.011387, Train MAPE: 4.128%, Val Loss: 0.020449, Val MAPE: 5.293%
# Epoch  79: Train Loss: 0.013160, Train MAPE: 4.586%, Val Loss: 0.022482, Val MAPE: 5.603%
# Epoch  80: Train Loss: 0.012058, Train MAPE: 4.349%, Val Loss: 0.027937, Val MAPE: 5.225%
# Epoch  81: Train Loss: 0.011898, Train MAPE: 4.106%, Val Loss: 0.021723, Val MAPE: 5.028%
# Epoch  82: Train Loss: 0.022400, Train MAPE: 5.514%, Val Loss: 0.028833, Val MAPE: 6.145%
# Epoch  83: Train Loss: 0.011472, Train MAPE: 4.065%, Val Loss: 0.021438, Val MAPE: 5.097%
# Epoch  84: Train Loss: 0.010935, Train MAPE: 4.140%, Val Loss: 0.020839, Val MAPE: 5.292%
# Epoch  85: Train Loss: 0.015312, Train MAPE: 5.202%, Val Loss: 0.022341, Val MAPE: 6.190%
# Epoch  86: Train Loss: 0.011672, Train MAPE: 4.255%, Val Loss: 0.020733, Val MAPE: 5.283%
# Epoch  87: Train Loss: 0.011268, Train MAPE: 3.834%, Val Loss: 0.021609, Val MAPE: 4.806%
# Epoch  88: Train Loss: 0.010433, Train MAPE: 3.891%, Val Loss: 0.020565, Val MAPE: 4.752%
# Epoch  89: Train Loss: 0.011056, Train MAPE: 3.802%, Val Loss: 0.020899, Val MAPE: 4.610%
# Epoch  90: Train Loss: 0.011418, Train MAPE: 4.214%, Val Loss: 0.020794, Val MAPE: 5.155%
# Epoch  91: Train Loss: 0.013016, Train MAPE: 4.087%, Val Loss: 0.021472, Val MAPE: 5.440%
# Epoch  92: Train Loss: 0.011755, Train MAPE: 4.766%, Val Loss: 0.020680, Val MAPE: 5.841%
# Epoch  93: Train Loss: 0.023868, Train MAPE: 4.699%, Val Loss: 0.036000, Val MAPE: 6.004%
# Epoch  94: Train Loss: 0.012186, Train MAPE: 4.587%, Val Loss: 0.022412, Val MAPE: 5.763%
# Epoch  95: Train Loss: 0.015029, Train MAPE: 4.510%, Val Loss: 0.024095, Val MAPE: 5.242%
# Epoch  96: Train Loss: 0.010232, Train MAPE: 3.923%, Val Loss: 0.020187, Val MAPE: 4.937%
# Epoch  97: Train Loss: 0.025845, Train MAPE: 5.317%, Val Loss: 0.029978, Val MAPE: 5.946%
# Epoch  98: Train Loss: 0.011730, Train MAPE: 3.833%, Val Loss: 0.054378, Val MAPE: 5.069%
# Epoch  99: Train Loss: 0.010326, Train MAPE: 4.396%, Val Loss: 0.019615, Val MAPE: 5.854%
# Epoch 100: Train Loss: 0.010202, Train MAPE: 3.705%, Val Loss: 0.019882, Val MAPE: 4.581%
# Epoch 101: Train Loss: 0.012284, Train MAPE: 4.152%, Val Loss: 0.020279, Val MAPE: 5.002%
# Epoch 102: Train Loss: 0.010565, Train MAPE: 4.195%, Val Loss: 0.019568, Val MAPE: 5.122%
# Epoch 103: Train Loss: 0.011554, Train MAPE: 4.168%, Val Loss: 0.021744, Val MAPE: 6.664%
# Epoch 104: Train Loss: 0.010568, Train MAPE: 3.787%, Val Loss: 0.018990, Val MAPE: 4.537%
# Epoch 105: Train Loss: 0.010139, Train MAPE: 3.981%, Val Loss: 0.019724, Val MAPE: 4.939%
# Epoch 106: Train Loss: 0.010334, Train MAPE: 3.655%, Val Loss: 0.018517, Val MAPE: 4.660%
# Epoch 107: Train Loss: 0.010275, Train MAPE: 4.351%, Val Loss: 0.018406, Val MAPE: 5.586%
# Epoch 108: Train Loss: 0.009734, Train MAPE: 4.188%, Val Loss: 0.018355, Val MAPE: 5.178%
# Epoch 109: Train Loss: 0.011691, Train MAPE: 4.012%, Val Loss: 0.019264, Val MAPE: 4.848%
# Epoch 110: Train Loss: 0.010000, Train MAPE: 4.057%, Val Loss: 0.018353, Val MAPE: 5.013%
# Epoch 111: Train Loss: 0.010760, Train MAPE: 4.524%, Val Loss: 0.018836, Val MAPE: 5.851%
# Epoch 112: Train Loss: 0.009388, Train MAPE: 3.602%, Val Loss: 0.019288, Val MAPE: 4.434%
# Epoch 113: Train Loss: 0.008856, Train MAPE: 3.752%, Val Loss: 0.018108, Val MAPE: 4.590%
# Epoch 114: Train Loss: 0.009800, Train MAPE: 3.572%, Val Loss: 0.018873, Val MAPE: 5.852%
# Epoch 115: Train Loss: 0.011339, Train MAPE: 3.987%, Val Loss: 0.020116, Val MAPE: 5.027%
# Epoch 116: Train Loss: 0.009602, Train MAPE: 3.926%, Val Loss: 0.018651, Val MAPE: 4.802%
# Epoch 117: Train Loss: 0.008819, Train MAPE: 3.815%, Val Loss: 0.018252, Val MAPE: 4.731%
# Epoch 118: Train Loss: 0.009102, Train MAPE: 3.943%, Val Loss: 0.017599, Val MAPE: 4.978%
# Epoch 119: Train Loss: 0.009243, Train MAPE: 3.965%, Val Loss: 0.018360, Val MAPE: 5.164%
# Epoch 120: Train Loss: 0.010418, Train MAPE: 3.979%, Val Loss: 0.017694, Val MAPE: 4.975%
# Epoch 121: Train Loss: 0.008820, Train MAPE: 3.545%, Val Loss: 0.018346, Val MAPE: 4.713%
# Epoch 122: Train Loss: 0.009275, Train MAPE: 3.943%, Val Loss: 0.019870, Val MAPE: 5.324%
# Epoch 123: Train Loss: 0.009045, Train MAPE: 3.818%, Val Loss: 0.018759, Val MAPE: 5.146%
# Epoch 124: Train Loss: 0.013873, Train MAPE: 3.998%, Val Loss: 0.022421, Val MAPE: 5.127%
# Epoch 125: Train Loss: 0.008528, Train MAPE: 3.679%, Val Loss: 0.018405, Val MAPE: 4.789%
# Epoch 126: Train Loss: 0.011403, Train MAPE: 4.168%, Val Loss: 0.017442, Val MAPE: 5.530%
# Epoch 127: Train Loss: 0.008853, Train MAPE: 3.871%, Val Loss: 0.017919, Val MAPE: 5.185%
# Epoch 128: Train Loss: 0.008135, Train MAPE: 3.396%, Val Loss: 0.017095, Val MAPE: 4.294%
# Epoch 129: Train Loss: 0.009357, Train MAPE: 3.774%, Val Loss: 0.020993, Val MAPE: 4.609%
# Epoch 130: Train Loss: 0.008842, Train MAPE: 3.569%, Val Loss: 0.017517, Val MAPE: 4.864%
# Epoch 131: Train Loss: 0.009859, Train MAPE: 3.650%, Val Loss: 0.018613, Val MAPE: 4.781%
# Epoch 132: Train Loss: 0.008214, Train MAPE: 3.444%, Val Loss: 0.016577, Val MAPE: 4.485%
# Epoch 133: Train Loss: 0.008080, Train MAPE: 3.449%, Val Loss: 0.016853, Val MAPE: 4.250%
# Epoch 134: Train Loss: 0.008472, Train MAPE: 4.053%, Val Loss: 0.015929, Val MAPE: 5.005%
# Epoch 135: Train Loss: 0.008328, Train MAPE: 3.534%, Val Loss: 0.017352, Val MAPE: 5.056%
# Epoch 136: Train Loss: 0.008745, Train MAPE: 3.908%, Val Loss: 0.016479, Val MAPE: 4.827%
# Epoch 137: Train Loss: 0.009136, Train MAPE: 4.043%, Val Loss: 0.017779, Val MAPE: 5.266%
# Epoch 138: Train Loss: 0.008149, Train MAPE: 3.974%, Val Loss: 0.016972, Val MAPE: 5.057%
# Epoch 139: Train Loss: 0.009550, Train MAPE: 3.699%, Val Loss: 0.017538, Val MAPE: 4.862%
# Epoch 140: Train Loss: 0.009306, Train MAPE: 3.799%, Val Loss: 0.022103, Val MAPE: 5.108%
# Epoch 141: Train Loss: 0.007876, Train MAPE: 3.779%, Val Loss: 0.016526, Val MAPE: 5.050%
# Epoch 142: Train Loss: 0.008434, Train MAPE: 3.427%, Val Loss: 0.015865, Val MAPE: 4.747%
# Epoch 143: Train Loss: 0.008926, Train MAPE: 3.897%, Val Loss: 0.016674, Val MAPE: 4.954%
# Epoch 144: Train Loss: 0.008232, Train MAPE: 3.363%, Val Loss: 0.018012, Val MAPE: 4.186%
# Epoch 145: Train Loss: 0.013663, Train MAPE: 4.153%, Val Loss: 0.023139, Val MAPE: 5.154%
# Epoch 146: Train Loss: 0.007816, Train MAPE: 3.795%, Val Loss: 0.016564, Val MAPE: 4.925%
# Epoch 147: Train Loss: 0.007376, Train MAPE: 3.936%, Val Loss: 0.016608, Val MAPE: 5.845%
# Epoch 148: Train Loss: 0.008623, Train MAPE: 4.114%, Val Loss: 0.017905, Val MAPE: 5.254%
# Epoch 149: Train Loss: 0.011947, Train MAPE: 3.800%, Val Loss: 0.020604, Val MAPE: 4.795%
# Epoch 150: Train Loss: 0.007735, Train MAPE: 3.590%, Val Loss: 0.016244, Val MAPE: 4.598%
# Epoch 151: Train Loss: 0.007845, Train MAPE: 3.484%, Val Loss: 0.016547, Val MAPE: 4.750%
# Epoch 152: Train Loss: 0.008499, Train MAPE: 4.009%, Val Loss: 0.016623, Val MAPE: 5.000%
# Epoch 153: Train Loss: 0.009048, Train MAPE: 3.978%, Val Loss: 0.017136, Val MAPE: 5.263%
# Epoch 154: Train Loss: 0.010013, Train MAPE: 3.545%, Val Loss: 0.019768, Val MAPE: 5.495%
# Epoch 155: Train Loss: 0.007653, Train MAPE: 3.366%, Val Loss: 0.016050, Val MAPE: 5.191%
# Epoch 156: Train Loss: 0.007528, Train MAPE: 3.359%, Val Loss: 0.016553, Val MAPE: 4.319%
# Epoch 157: Train Loss: 0.008410, Train MAPE: 3.687%, Val Loss: 0.016954, Val MAPE: 5.050%
# Epoch 158: Train Loss: 0.007441, Train MAPE: 3.457%, Val Loss: 0.016190, Val MAPE: 4.431%
# Epoch 159: Train Loss: 0.007431, Train MAPE: 3.342%, Val Loss: 0.016351, Val MAPE: 4.426%
# Epoch 160: Train Loss: 0.007124, Train MAPE: 3.391%, Val Loss: 0.016439, Val MAPE: 4.444%
# Epoch 161: Train Loss: 0.009798, Train MAPE: 4.060%, Val Loss: 0.018552, Val MAPE: 5.235%
# Epoch 162: Train Loss: 0.007262, Train MAPE: 3.533%, Val Loss: 0.016298, Val MAPE: 4.403%
# Epoch 163: Train Loss: 0.007477, Train MAPE: 3.451%, Val Loss: 0.016605, Val MAPE: 4.585%
# Epoch 164: Train Loss: 0.015202, Train MAPE: 3.855%, Val Loss: 0.026105, Val MAPE: 4.935%
# Epoch 165: Train Loss: 0.009593, Train MAPE: 3.599%, Val Loss: 0.019079, Val MAPE: 4.667%
# Epoch 166: Train Loss: 0.006891, Train MAPE: 3.421%, Val Loss: 0.016754, Val MAPE: 4.338%
# Epoch 167: Train Loss: 0.007288, Train MAPE: 3.268%, Val Loss: 0.016389, Val MAPE: 4.485%
# Epoch 168: Train Loss: 0.007282, Train MAPE: 3.648%, Val Loss: 0.015867, Val MAPE: 4.850%
# Epoch 169: Train Loss: 0.006937, Train MAPE: 3.345%, Val Loss: 0.015826, Val MAPE: 4.399%
# Epoch 170: Train Loss: 0.008048, Train MAPE: 3.272%, Val Loss: 0.016040, Val MAPE: 4.194%
# Epoch 171: Train Loss: 0.007006, Train MAPE: 3.365%, Val Loss: 0.015673, Val MAPE: 4.284%
# Epoch 172: Train Loss: 0.007326, Train MAPE: 3.184%, Val Loss: 0.016756, Val MAPE: 4.512%
# Epoch 173: Train Loss: 0.007901, Train MAPE: 3.719%, Val Loss: 0.018119, Val MAPE: 4.849%
# Epoch 174: Train Loss: 0.007452, Train MAPE: 3.256%, Val Loss: 0.016462, Val MAPE: 4.400%
# Epoch 175: Train Loss: 0.006987, Train MAPE: 3.594%, Val Loss: 0.015354, Val MAPE: 4.666%
# Epoch 176: Train Loss: 0.007413, Train MAPE: 3.571%, Val Loss: 0.015632, Val MAPE: 4.602%
# Epoch 177: Train Loss: 0.007808, Train MAPE: 3.827%, Val Loss: 0.017798, Val MAPE: 4.777%
# Epoch 178: Train Loss: 0.007116, Train MAPE: 3.462%, Val Loss: 0.015328, Val MAPE: 4.361%
# Epoch 179: Train Loss: 0.006434, Train MAPE: 3.157%, Val Loss: 0.014691, Val MAPE: 4.221%
# Epoch 180: Train Loss: 0.006498, Train MAPE: 3.290%, Val Loss: 0.014718, Val MAPE: 4.247%
# Epoch 181: Train Loss: 0.008197, Train MAPE: 4.040%, Val Loss: 0.015441, Val MAPE: 7.358%
# Epoch 182: Train Loss: 0.007463, Train MAPE: 3.393%, Val Loss: 0.015358, Val MAPE: 4.422%
# Epoch 183: Train Loss: 0.006702, Train MAPE: 3.302%, Val Loss: 0.014968, Val MAPE: 4.414%
# Epoch 184: Train Loss: 0.007486, Train MAPE: 3.175%, Val Loss: 0.015130, Val MAPE: 4.332%
# Epoch 185: Train Loss: 0.006515, Train MAPE: 2.956%, Val Loss: 0.014846, Val MAPE: 4.008%
# Epoch 186: Train Loss: 0.006572, Train MAPE: 2.877%, Val Loss: 0.015959, Val MAPE: 3.835%
# Epoch 187: Train Loss: 0.006507, Train MAPE: 3.328%, Val Loss: 0.014101, Val MAPE: 4.359%
# Epoch 188: Train Loss: 0.007330, Train MAPE: 3.417%, Val Loss: 0.015683, Val MAPE: 4.640%
# Epoch 189: Train Loss: 0.006460, Train MAPE: 3.077%, Val Loss: 0.014712, Val MAPE: 4.174%
# Epoch 190: Train Loss: 0.007712, Train MAPE: 3.474%, Val Loss: 0.015997, Val MAPE: 4.529%
# Epoch 191: Train Loss: 0.007103, Train MAPE: 3.189%, Val Loss: 0.016200, Val MAPE: 4.318%
# Epoch 192: Train Loss: 0.008592, Train MAPE: 3.808%, Val Loss: 0.016598, Val MAPE: 4.989%
# Epoch 193: Train Loss: 0.008327, Train MAPE: 3.539%, Val Loss: 0.016739, Val MAPE: 4.729%
# Epoch 194: Train Loss: 0.006102, Train MAPE: 3.092%, Val Loss: 0.015158, Val MAPE: 4.437%
# Epoch 195: Train Loss: 0.007019, Train MAPE: 3.020%, Val Loss: 0.015017, Val MAPE: 4.014%
# Epoch 196: Train Loss: 0.006853, Train MAPE: 3.024%, Val Loss: 0.015126, Val MAPE: 3.997%
# Epoch 197: Train Loss: 0.006603, Train MAPE: 3.182%, Val Loss: 0.014989, Val MAPE: 4.116%
# Epoch 198: Train Loss: 0.006656, Train MAPE: 3.778%, Val Loss: 0.014844, Val MAPE: 8.942%
# Epoch 199: Train Loss: 0.006955, Train MAPE: 3.194%, Val Loss: 0.015573, Val MAPE: 4.397%
# Epoch 200: Train Loss: 0.006959, Train MAPE: 2.974%, Val Loss: 0.015930, Val MAPE: 3.989%
# Epoch 201: Train Loss: 0.006227, Train MAPE: 3.209%, Val Loss: 0.014511, Val MAPE: 4.198%
# Epoch 202: Train Loss: 0.006647, Train MAPE: 3.287%, Val Loss: 0.014373, Val MAPE: 4.402%
# Epoch 203: Train Loss: 0.005998, Train MAPE: 3.025%, Val Loss: 0.015136, Val MAPE: 4.093%
# Epoch 204: Train Loss: 0.006408, Train MAPE: 3.039%, Val Loss: 0.015642, Val MAPE: 4.015%
# Epoch 205: Train Loss: 0.006992, Train MAPE: 2.949%, Val Loss: 0.015569, Val MAPE: 4.034%
# Epoch 206: Train Loss: 0.006758, Train MAPE: 3.235%, Val Loss: 0.016299, Val MAPE: 4.396%
# Epoch 207: Train Loss: 0.008921, Train MAPE: 3.176%, Val Loss: 0.016784, Val MAPE: 4.260%
# Epoch 208: Train Loss: 0.006955, Train MAPE: 2.978%, Val Loss: 0.015634, Val MAPE: 4.229%
# Epoch 209: Train Loss: 0.006008, Train MAPE: 3.074%, Val Loss: 0.016070, Val MAPE: 4.232%
# Epoch 210: Train Loss: 0.006364, Train MAPE: 3.247%, Val Loss: 0.014818, Val MAPE: 4.509%
# Epoch 211: Train Loss: 0.006366, Train MAPE: 3.376%, Val Loss: 0.015337, Val MAPE: 4.598%
# Epoch 212: Train Loss: 0.006125, Train MAPE: 3.178%, Val Loss: 0.014160, Val MAPE: 4.373%
# Epoch 213: Train Loss: 0.007621, Train MAPE: 4.377%, Val Loss: 0.015455, Val MAPE: 5.882%
# Epoch 214: Train Loss: 0.007242, Train MAPE: 3.155%, Val Loss: 0.017059, Val MAPE: 4.478%
# Epoch 215: Train Loss: 0.008517, Train MAPE: 3.681%, Val Loss: 0.016993, Val MAPE: 4.977%
# Epoch 216: Train Loss: 0.006494, Train MAPE: 3.268%, Val Loss: 0.014996, Val MAPE: 4.227%
# Epoch 217: Train Loss: 0.007383, Train MAPE: 3.642%, Val Loss: 0.016482, Val MAPE: 4.686%
# Epoch 218: Train Loss: 0.006201, Train MAPE: 3.017%, Val Loss: 0.014875, Val MAPE: 4.237%
# Epoch 219: Train Loss: 0.006027, Train MAPE: 2.928%, Val Loss: 0.014495, Val MAPE: 5.187%
# Epoch 220: Train Loss: 0.007084, Train MAPE: 3.030%, Val Loss: 0.015717, Val MAPE: 3.957%
# Epoch 221: Train Loss: 0.007046, Train MAPE: 3.239%, Val Loss: 0.015412, Val MAPE: 4.190%
# Epoch 222: Train Loss: 0.006186, Train MAPE: 2.857%, Val Loss: 0.014699, Val MAPE: 4.293%
# Epoch 223: Train Loss: 0.006205, Train MAPE: 2.958%, Val Loss: 0.014177, Val MAPE: 4.098%
# Epoch 224: Train Loss: 0.006369, Train MAPE: 2.783%, Val Loss: 0.014243, Val MAPE: 3.803%
# Epoch 225: Train Loss: 0.005579, Train MAPE: 3.176%, Val Loss: 0.020747, Val MAPE: 4.301%
# Epoch 226: Train Loss: 0.005822, Train MAPE: 2.908%, Val Loss: 0.013512, Val MAPE: 3.859%
# Epoch 227: Train Loss: 0.005672, Train MAPE: 3.085%, Val Loss: 0.015024, Val MAPE: 4.430%
# Epoch 228: Train Loss: 0.007844, Train MAPE: 3.798%, Val Loss: 0.016755, Val MAPE: 5.273%
# Epoch 229: Train Loss: 0.006110, Train MAPE: 3.004%, Val Loss: 0.014940, Val MAPE: 4.163%
# Epoch 230: Train Loss: 0.006375, Train MAPE: 3.354%, Val Loss: 0.015355, Val MAPE: 4.647%
# Epoch 231: Train Loss: 0.005824, Train MAPE: 3.105%, Val Loss: 0.015581, Val MAPE: 4.267%
# Epoch 232: Train Loss: 0.006088, Train MAPE: 3.318%, Val Loss: 0.014509, Val MAPE: 4.599%
# Epoch 233: Train Loss: 0.005512, Train MAPE: 3.071%, Val Loss: 0.014063, Val MAPE: 4.091%
# Epoch 234: Train Loss: 0.005757, Train MAPE: 2.889%, Val Loss: 0.014814, Val MAPE: 3.778%
# Epoch 235: Train Loss: 0.005774, Train MAPE: 3.124%, Val Loss: 0.014506, Val MAPE: 4.152%
# Epoch 236: Train Loss: 0.006928, Train MAPE: 3.070%, Val Loss: 0.015131, Val MAPE: 4.051%
# Epoch 237: Train Loss: 0.005966, Train MAPE: 3.269%, Val Loss: 0.013836, Val MAPE: 4.148%
# Epoch 238: Train Loss: 0.005573, Train MAPE: 2.949%, Val Loss: 0.013643, Val MAPE: 4.248%
# Epoch 239: Train Loss: 0.008142, Train MAPE: 3.216%, Val Loss: 0.015564, Val MAPE: 4.301%
# Epoch 240: Train Loss: 0.006837, Train MAPE: 2.958%, Val Loss: 0.016282, Val MAPE: 4.867%
# Epoch 241: Train Loss: 0.006781, Train MAPE: 3.196%, Val Loss: 0.015983, Val MAPE: 4.282%
# Epoch 242: Train Loss: 0.006122, Train MAPE: 3.352%, Val Loss: 0.014145, Val MAPE: 4.559%
# Epoch 243: Train Loss: 0.005817, Train MAPE: 3.053%, Val Loss: 0.015258, Val MAPE: 3.912%
# Epoch 244: Train Loss: 0.005977, Train MAPE: 3.613%, Val Loss: 0.014658, Val MAPE: 4.925%
# Epoch 245: Train Loss: 0.006012, Train MAPE: 2.980%, Val Loss: 0.015535, Val MAPE: 4.012%
# Epoch 246: Train Loss: 0.005676, Train MAPE: 2.956%, Val Loss: 0.015315, Val MAPE: 3.915%
# Epoch 247: Train Loss: 0.006017, Train MAPE: 3.353%, Val Loss: 0.015106, Val MAPE: 4.314%
# Epoch 248: Train Loss: 0.007347, Train MAPE: 3.266%, Val Loss: 0.018114, Val MAPE: 5.211%
# Epoch 249: Train Loss: 0.005770, Train MAPE: 2.806%, Val Loss: 0.018209, Val MAPE: 3.879%
# Epoch 250: Train Loss: 0.005972, Train MAPE: 3.879%, Val Loss: 0.014412, Val MAPE: 5.376%
# Epoch 251: Train Loss: 0.005867, Train MAPE: 3.196%, Val Loss: 0.014759, Val MAPE: 4.365%
# Epoch 252: Train Loss: 0.005790, Train MAPE: 2.954%, Val Loss: 0.014790, Val MAPE: 4.246%
# Epoch 253: Train Loss: 0.007392, Train MAPE: 2.994%, Val Loss: 0.016593, Val MAPE: 4.016%
# Epoch 254: Train Loss: 0.006718, Train MAPE: 2.933%, Val Loss: 0.015048, Val MAPE: 3.927%
# Epoch 255: Train Loss: 0.006751, Train MAPE: 3.433%, Val Loss: 0.014682, Val MAPE: 5.168%
# Epoch 256: Train Loss: 0.005657, Train MAPE: 3.255%, Val Loss: 0.014542, Val MAPE: 4.521%
# Epoch 257: Train Loss: 0.007240, Train MAPE: 3.455%, Val Loss: 0.016589, Val MAPE: 6.602%
# Epoch 258: Train Loss: 0.005997, Train MAPE: 2.896%, Val Loss: 0.015055, Val MAPE: 4.200%
# Epoch 259: Train Loss: 0.006743, Train MAPE: 3.243%, Val Loss: 0.016099, Val MAPE: 4.514%
# Epoch 260: Train Loss: 0.005416, Train MAPE: 2.953%, Val Loss: 0.014672, Val MAPE: 4.162%
# Epoch 261: Train Loss: 0.006474, Train MAPE: 3.193%, Val Loss: 0.015083, Val MAPE: 4.442%
# Epoch 262: Train Loss: 0.005908, Train MAPE: 3.095%, Val Loss: 0.015383, Val MAPE: 4.219%
# Epoch 263: Train Loss: 0.007200, Train MAPE: 3.128%, Val Loss: 0.015080, Val MAPE: 4.128%
# Epoch 264: Train Loss: 0.005238, Train MAPE: 3.151%, Val Loss: 0.013676, Val MAPE: 4.373%
# Epoch 265: Train Loss: 0.006687, Train MAPE: 3.283%, Val Loss: 0.014090, Val MAPE: 4.253%
# Epoch 266: Train Loss: 0.005130, Train MAPE: 3.265%, Val Loss: 0.014042, Val MAPE: 4.432%
# Epoch 267: Train Loss: 0.007054, Train MAPE: 3.029%, Val Loss: 0.015185, Val MAPE: 4.110%
# Epoch 268: Train Loss: 0.005576, Train MAPE: 3.003%, Val Loss: 0.014663, Val MAPE: 3.992%
# Epoch 269: Train Loss: 0.006153, Train MAPE: 3.157%, Val Loss: 0.015306, Val MAPE: 4.219%
# Epoch 270: Train Loss: 0.005175, Train MAPE: 2.846%, Val Loss: 0.014438, Val MAPE: 3.869%
# Epoch 271: Train Loss: 0.005666, Train MAPE: 3.504%, Val Loss: 0.014783, Val MAPE: 4.589%
# Epoch 272: Train Loss: 0.005620, Train MAPE: 2.932%, Val Loss: 0.014650, Val MAPE: 3.961%
# Epoch 273: Train Loss: 0.006465, Train MAPE: 2.789%, Val Loss: 0.015232, Val MAPE: 3.971%
# Epoch 274: Train Loss: 0.005098, Train MAPE: 2.972%, Val Loss: 0.014138, Val MAPE: 4.048%
# Epoch 275: Train Loss: 0.005180, Train MAPE: 3.139%, Val Loss: 0.013636, Val MAPE: 4.091%
# Epoch 276: Train Loss: 0.006231, Train MAPE: 3.049%, Val Loss: 0.014416, Val MAPE: 4.129%
# Epoch 277: Train Loss: 0.005816, Train MAPE: 2.830%, Val Loss: 0.015465, Val MAPE: 3.772%
# Epoch 278: Train Loss: 0.005133, Train MAPE: 3.180%, Val Loss: 0.014474, Val MAPE: 4.220%
# Epoch 279: Train Loss: 0.005037, Train MAPE: 2.718%, Val Loss: 0.014865, Val MAPE: 3.531%
# Epoch 280: Train Loss: 0.004930, Train MAPE: 2.803%, Val Loss: 0.013228, Val MAPE: 3.827%
# Epoch 281: Train Loss: 0.005293, Train MAPE: 3.092%, Val Loss: 0.014547, Val MAPE: 4.077%
# Epoch 282: Train Loss: 0.005636, Train MAPE: 3.095%, Val Loss: 0.014487, Val MAPE: 4.014%
# Epoch 283: Train Loss: 0.005496, Train MAPE: 2.992%, Val Loss: 0.015632, Val MAPE: 3.933%
# Epoch 284: Train Loss: 0.005993, Train MAPE: 3.206%, Val Loss: 0.014539, Val MAPE: 4.292%
# Epoch 285: Train Loss: 0.005578, Train MAPE: 2.964%, Val Loss: 0.014988, Val MAPE: 3.698%
# Epoch 286: Train Loss: 0.005736, Train MAPE: 3.021%, Val Loss: 0.015873, Val MAPE: 3.982%
# Epoch 287: Train Loss: 0.005183, Train MAPE: 3.058%, Val Loss: 0.013455, Val MAPE: 4.096%
# Epoch 288: Train Loss: 0.005416, Train MAPE: 3.143%, Val Loss: 0.013392, Val MAPE: 4.250%
# Epoch 289: Train Loss: 0.005754, Train MAPE: 3.212%, Val Loss: 0.015070, Val MAPE: 4.295%
# Epoch 290: Train Loss: 0.005064, Train MAPE: 3.210%, Val Loss: 0.014183, Val MAPE: 4.166%
# Epoch 291: Train Loss: 0.006483, Train MAPE: 3.285%, Val Loss: 0.015005, Val MAPE: 4.549%
# Epoch 292: Train Loss: 0.005545, Train MAPE: 2.965%, Val Loss: 0.013873, Val MAPE: 4.073%
# Epoch 293: Train Loss: 0.005075, Train MAPE: 2.874%, Val Loss: 0.013483, Val MAPE: 4.472%
# Epoch 294: Train Loss: 0.005322, Train MAPE: 3.703%, Val Loss: 0.014087, Val MAPE: 4.999%
# Epoch 295: Train Loss: 0.005492, Train MAPE: 2.756%, Val Loss: 0.013074, Val MAPE: 3.829%
# Epoch 296: Train Loss: 0.005010, Train MAPE: 3.203%, Val Loss: 0.014032, Val MAPE: 4.230%
# Epoch 297: Train Loss: 0.005704, Train MAPE: 2.943%, Val Loss: 0.013808, Val MAPE: 4.170%
# Epoch 298: Train Loss: 0.004884, Train MAPE: 3.110%, Val Loss: 0.013923, Val MAPE: 4.228%
# Epoch 299: Train Loss: 0.005758, Train MAPE: 3.142%, Val Loss: 0.013769, Val MAPE: 4.181%
# Epoch 300: Train Loss: 0.006202, Train MAPE: 3.019%, Val Loss: 0.016297, Val MAPE: 3.987%
# Epoch 301: Train Loss: 0.004806, Train MAPE: 2.716%, Val Loss: 0.013621, Val MAPE: 3.661%
# Epoch 302: Train Loss: 0.006497, Train MAPE: 3.045%, Val Loss: 0.015031, Val MAPE: 4.038%
# Epoch 303: Train Loss: 0.004653, Train MAPE: 3.225%, Val Loss: 0.013395, Val MAPE: 6.128%
# Epoch 304: Train Loss: 0.005397, Train MAPE: 2.909%, Val Loss: 0.014940, Val MAPE: 3.939%
# Epoch 305: Train Loss: 0.005687, Train MAPE: 3.119%, Val Loss: 0.015527, Val MAPE: 3.941%
# Epoch 306: Train Loss: 0.005419, Train MAPE: 3.071%, Val Loss: 0.013579, Val MAPE: 3.760%
# Epoch 307: Train Loss: 0.004807, Train MAPE: 3.004%, Val Loss: 0.014188, Val MAPE: 4.129%
# Epoch 308: Train Loss: 0.005323, Train MAPE: 3.207%, Val Loss: 0.013853, Val MAPE: 4.330%
# Epoch 309: Train Loss: 0.005219, Train MAPE: 3.162%, Val Loss: 0.013786, Val MAPE: 4.170%
# Epoch 310: Train Loss: 0.004894, Train MAPE: 3.021%, Val Loss: 0.013572, Val MAPE: 3.991%
# Epoch 311: Train Loss: 0.005365, Train MAPE: 3.081%, Val Loss: 0.014934, Val MAPE: 4.014%
# Epoch 312: Train Loss: 0.004631, Train MAPE: 2.801%, Val Loss: 0.013993, Val MAPE: 3.846%
# Epoch 313: Train Loss: 0.004948, Train MAPE: 2.902%, Val Loss: 0.013985, Val MAPE: 3.780%
# Epoch 314: Train Loss: 0.004457, Train MAPE: 2.785%, Val Loss: 0.014183, Val MAPE: 4.810%
# Epoch 315: Train Loss: 0.005196, Train MAPE: 3.093%, Val Loss: 0.013761, Val MAPE: 4.295%
# Epoch 316: Train Loss: 0.005835, Train MAPE: 3.124%, Val Loss: 0.014427, Val MAPE: 4.333%
# Epoch 317: Train Loss: 0.006017, Train MAPE: 3.261%, Val Loss: 0.014198, Val MAPE: 4.278%
# Epoch 318: Train Loss: 0.006625, Train MAPE: 2.906%, Val Loss: 0.015992, Val MAPE: 3.753%
# Epoch 319: Train Loss: 0.004871, Train MAPE: 3.263%, Val Loss: 0.013842, Val MAPE: 4.506%
# Epoch 320: Train Loss: 0.005570, Train MAPE: 2.811%, Val Loss: 0.014710, Val MAPE: 3.803%
# Epoch 321: Train Loss: 0.004171, Train MAPE: 2.683%, Val Loss: 0.012719, Val MAPE: 3.665%
# Epoch 322: Train Loss: 0.005104, Train MAPE: 2.977%, Val Loss: 0.014018, Val MAPE: 3.774%
# Epoch 323: Train Loss: 0.004712, Train MAPE: 2.871%, Val Loss: 0.013773, Val MAPE: 3.815%
# Epoch 324: Train Loss: 0.005000, Train MAPE: 3.146%, Val Loss: 0.014213, Val MAPE: 4.692%
# Epoch 325: Train Loss: 0.005655, Train MAPE: 3.004%, Val Loss: 0.015703, Val MAPE: 3.780%
# Epoch 326: Train Loss: 0.005413, Train MAPE: 3.420%, Val Loss: 0.014026, Val MAPE: 4.834%
# Epoch 327: Train Loss: 0.005368, Train MAPE: 3.353%, Val Loss: 0.014796, Val MAPE: 4.352%
# Epoch 328: Train Loss: 0.004680, Train MAPE: 2.853%, Val Loss: 0.015504, Val MAPE: 3.961%
# Epoch 329: Train Loss: 0.004752, Train MAPE: 2.674%, Val Loss: 0.013578, Val MAPE: 3.516%
# Epoch 330: Train Loss: 0.004362, Train MAPE: 2.868%, Val Loss: 0.012824, Val MAPE: 3.795%
# Epoch 331: Train Loss: 0.004815, Train MAPE: 2.848%, Val Loss: 0.013824, Val MAPE: 3.579%
# Epoch 332: Train Loss: 0.004351, Train MAPE: 2.774%, Val Loss: 0.012936, Val MAPE: 3.736%
# Epoch 333: Train Loss: 0.007196, Train MAPE: 3.338%, Val Loss: 0.016042, Val MAPE: 4.251%
# Epoch 334: Train Loss: 0.004776, Train MAPE: 2.938%, Val Loss: 0.014158, Val MAPE: 3.780%
# Epoch 335: Train Loss: 0.006305, Train MAPE: 2.955%, Val Loss: 0.015824, Val MAPE: 3.835%
# Epoch 336: Train Loss: 0.004955, Train MAPE: 2.687%, Val Loss: 0.014524, Val MAPE: 3.652%
# Epoch 337: Train Loss: 0.004517, Train MAPE: 2.745%, Val Loss: 0.013819, Val MAPE: 3.546%
# Epoch 338: Train Loss: 0.004713, Train MAPE: 3.113%, Val Loss: 0.014437, Val MAPE: 3.941%
# Epoch 339: Train Loss: 0.004715, Train MAPE: 2.895%, Val Loss: 0.012737, Val MAPE: 3.728%
# Epoch 340: Train Loss: 0.005219, Train MAPE: 2.909%, Val Loss: 0.014410, Val MAPE: 3.942%
# Epoch 341: Train Loss: 0.005780, Train MAPE: 3.123%, Val Loss: 0.014616, Val MAPE: 4.412%
# Epoch 342: Train Loss: 0.004277, Train MAPE: 2.702%, Val Loss: 0.013392, Val MAPE: 4.060%
# Epoch 343: Train Loss: 0.004823, Train MAPE: 2.853%, Val Loss: 0.012760, Val MAPE: 3.718%
# Epoch 344: Train Loss: 0.004627, Train MAPE: 2.844%, Val Loss: 0.013578, Val MAPE: 3.962%
# Epoch 345: Train Loss: 0.004052, Train MAPE: 2.675%, Val Loss: 0.012953, Val MAPE: 3.736%
# Epoch 346: Train Loss: 0.004727, Train MAPE: 2.785%, Val Loss: 0.013238, Val MAPE: 3.807%
# Epoch 347: Train Loss: 0.004776, Train MAPE: 3.250%, Val Loss: 0.014521, Val MAPE: 4.678%
# Epoch 348: Train Loss: 0.005398, Train MAPE: 3.228%, Val Loss: 0.014606, Val MAPE: 4.594%
# Epoch 349: Train Loss: 0.004903, Train MAPE: 3.124%, Val Loss: 0.014598, Val MAPE: 4.152%
# Epoch 350: Train Loss: 0.005203, Train MAPE: 2.700%, Val Loss: 0.013367, Val MAPE: 3.757%
# Epoch 351: Train Loss: 0.004987, Train MAPE: 3.169%, Val Loss: 0.014383, Val MAPE: 3.970%
# Epoch 352: Train Loss: 0.003982, Train MAPE: 2.707%, Val Loss: 0.012450, Val MAPE: 3.557%
# Epoch 353: Train Loss: 0.006563, Train MAPE: 3.408%, Val Loss: 0.014639, Val MAPE: 4.200%
# Epoch 354: Train Loss: 0.004417, Train MAPE: 2.625%, Val Loss: 0.012894, Val MAPE: 3.512%
# Epoch 355: Train Loss: 0.004120, Train MAPE: 2.774%, Val Loss: 0.012673, Val MAPE: 4.205%
# Epoch 356: Train Loss: 0.004166, Train MAPE: 2.734%, Val Loss: 0.012875, Val MAPE: 3.785%
# Epoch 357: Train Loss: 0.004176, Train MAPE: 2.874%, Val Loss: 0.013158, Val MAPE: 3.748%
# Epoch 358: Train Loss: 0.004239, Train MAPE: 2.969%, Val Loss: 0.012395, Val MAPE: 3.936%
# Epoch 359: Train Loss: 0.004332, Train MAPE: 3.071%, Val Loss: 0.013489, Val MAPE: 4.409%
# Epoch 360: Train Loss: 0.004915, Train MAPE: 3.166%, Val Loss: 0.014563, Val MAPE: 4.187%
# Epoch 361: Train Loss: 0.005776, Train MAPE: 3.101%, Val Loss: 0.014909, Val MAPE: 4.648%
# Epoch 362: Train Loss: 0.004612, Train MAPE: 2.623%, Val Loss: 0.013150, Val MAPE: 3.730%
# Epoch 363: Train Loss: 0.003937, Train MAPE: 2.705%, Val Loss: 0.013078, Val MAPE: 3.534%
# Epoch 364: Train Loss: 0.004931, Train MAPE: 3.074%, Val Loss: 0.013947, Val MAPE: 4.090%
# Epoch 365: Train Loss: 0.004611, Train MAPE: 2.836%, Val Loss: 0.015476, Val MAPE: 4.670%
# Epoch 366: Train Loss: 0.004241, Train MAPE: 2.766%, Val Loss: 0.013016, Val MAPE: 3.901%
# Epoch 367: Train Loss: 0.004072, Train MAPE: 2.818%, Val Loss: 0.012359, Val MAPE: 4.113%
# Epoch 368: Train Loss: 0.004214, Train MAPE: 2.968%, Val Loss: 0.014152, Val MAPE: 4.248%
# Epoch 369: Train Loss: 0.004399, Train MAPE: 2.802%, Val Loss: 0.013617, Val MAPE: 3.784%
# Epoch 370: Train Loss: 0.004641, Train MAPE: 3.004%, Val Loss: 0.014314, Val MAPE: 4.076%
# Epoch 371: Train Loss: 0.004041, Train MAPE: 2.766%, Val Loss: 0.013605, Val MAPE: 3.643%
# Epoch 372: Train Loss: 0.005515, Train MAPE: 2.897%, Val Loss: 0.015145, Val MAPE: 4.602%
# Epoch 373: Train Loss: 0.004163, Train MAPE: 3.664%, Val Loss: 0.011975, Val MAPE: 4.646%
# Epoch 374: Train Loss: 0.005193, Train MAPE: 2.889%, Val Loss: 0.014843, Val MAPE: 3.990%
# Epoch 375: Train Loss: 0.003789, Train MAPE: 2.676%, Val Loss: 0.013342, Val MAPE: 3.718%
# Epoch 376: Train Loss: 0.003986, Train MAPE: 2.911%, Val Loss: 0.012499, Val MAPE: 4.010%
# Epoch 377: Train Loss: 0.004061, Train MAPE: 2.653%, Val Loss: 0.012562, Val MAPE: 3.466%
# Epoch 378: Train Loss: 0.004774, Train MAPE: 3.029%, Val Loss: 0.014525, Val MAPE: 4.550%
# Epoch 379: Train Loss: 0.003800, Train MAPE: 2.910%, Val Loss: 0.012583, Val MAPE: 3.863%
# Epoch 380: Train Loss: 0.003739, Train MAPE: 2.503%, Val Loss: 0.013354, Val MAPE: 3.263%
# Epoch 381: Train Loss: 0.004744, Train MAPE: 3.103%, Val Loss: 0.013587, Val MAPE: 4.113%
# Epoch 382: Train Loss: 0.003944, Train MAPE: 2.692%, Val Loss: 0.013466, Val MAPE: 3.848%
# Epoch 383: Train Loss: 0.004198, Train MAPE: 2.786%, Val Loss: 0.012166, Val MAPE: 3.779%
# Epoch 384: Train Loss: 0.004435, Train MAPE: 2.957%, Val Loss: 0.014174, Val MAPE: 3.981%
# Epoch 385: Train Loss: 0.004306, Train MAPE: 2.723%, Val Loss: 0.014554, Val MAPE: 3.627%
# Epoch 386: Train Loss: 0.003944, Train MAPE: 2.835%, Val Loss: 0.012564, Val MAPE: 3.898%
# Epoch 387: Train Loss: 0.004001, Train MAPE: 2.759%, Val Loss: 0.013343, Val MAPE: 3.815%
# Epoch 388: Train Loss: 0.004490, Train MAPE: 2.610%, Val Loss: 0.013752, Val MAPE: 3.625%
# Epoch 389: Train Loss: 0.004609, Train MAPE: 3.051%, Val Loss: 0.012821, Val MAPE: 4.192%
# Epoch 390: Train Loss: 0.003999, Train MAPE: 3.129%, Val Loss: 0.012358, Val MAPE: 4.277%
# Epoch 391: Train Loss: 0.004470, Train MAPE: 3.145%, Val Loss: 0.013508, Val MAPE: 4.152%
# Epoch 392: Train Loss: 0.004503, Train MAPE: 2.895%, Val Loss: 0.012779, Val MAPE: 3.967%
# Epoch 393: Train Loss: 0.003918, Train MAPE: 2.800%, Val Loss: 0.012756, Val MAPE: 3.939%
# Epoch 394: Train Loss: 0.004298, Train MAPE: 3.020%, Val Loss: 0.012951, Val MAPE: 4.066%
# Epoch 395: Train Loss: 0.003854, Train MAPE: 2.761%, Val Loss: 0.014023, Val MAPE: 3.836%
# Epoch 396: Train Loss: 0.004672, Train MAPE: 3.086%, Val Loss: 0.014701, Val MAPE: 4.036%
# Epoch 397: Train Loss: 0.003815, Train MAPE: 2.756%, Val Loss: 0.013199, Val MAPE: 3.838%
# Epoch 398: Train Loss: 0.004262, Train MAPE: 2.826%, Val Loss: 0.014498, Val MAPE: 3.823%
# Epoch 399: Train Loss: 0.004477, Train MAPE: 3.081%, Val Loss: 0.012867, Val MAPE: 4.004%
# Epoch 400: Train Loss: 0.003899, Train MAPE: 2.792%, Val Loss: 0.013992, Val MAPE: 3.593%
# Epoch 401: Train Loss: 0.003533, Train MAPE: 2.706%, Val Loss: 0.011831, Val MAPE: 3.844%
# Epoch 402: Train Loss: 0.003456, Train MAPE: 3.027%, Val Loss: 0.012177, Val MAPE: 3.940%
# Epoch 403: Train Loss: 0.004954, Train MAPE: 2.705%, Val Loss: 0.014681, Val MAPE: 3.546%
# Epoch 404: Train Loss: 0.003694, Train MAPE: 2.855%, Val Loss: 0.012586, Val MAPE: 3.740%
# Epoch 405: Train Loss: 0.004155, Train MAPE: 2.813%, Val Loss: 0.013654, Val MAPE: 3.615%
# Epoch 406: Train Loss: 0.003712, Train MAPE: 2.719%, Val Loss: 0.012933, Val MAPE: 3.781%
# Epoch 407: Train Loss: 0.003720, Train MAPE: 2.964%, Val Loss: 0.013337, Val MAPE: 3.932%
# Epoch 408: Train Loss: 0.004617, Train MAPE: 2.949%, Val Loss: 0.013459, Val MAPE: 3.835%
# Epoch 409: Train Loss: 0.003704, Train MAPE: 2.615%, Val Loss: 0.012853, Val MAPE: 3.518%
# Epoch 410: Train Loss: 0.003483, Train MAPE: 2.627%, Val Loss: 0.011805, Val MAPE: 3.341%
# Epoch 411: Train Loss: 0.003537, Train MAPE: 2.641%, Val Loss: 0.012505, Val MAPE: 3.566%
# Epoch 412: Train Loss: 0.003399, Train MAPE: 2.727%, Val Loss: 0.012794, Val MAPE: 3.602%
# Epoch 413: Train Loss: 0.004693, Train MAPE: 2.809%, Val Loss: 0.014568, Val MAPE: 3.626%
# Epoch 414: Train Loss: 0.005141, Train MAPE: 3.104%, Val Loss: 0.014014, Val MAPE: 4.016%
# Epoch 415: Train Loss: 0.003250, Train MAPE: 2.695%, Val Loss: 0.011981, Val MAPE: 3.700%
# Epoch 416: Train Loss: 0.004610, Train MAPE: 3.566%, Val Loss: 0.014482, Val MAPE: 5.187%
# Epoch 417: Train Loss: 0.003549, Train MAPE: 2.655%, Val Loss: 0.012467, Val MAPE: 3.521%
# Epoch 418: Train Loss: 0.004432, Train MAPE: 3.029%, Val Loss: 0.014451, Val MAPE: 4.055%
# Epoch 419: Train Loss: 0.004373, Train MAPE: 3.262%, Val Loss: 0.015061, Val MAPE: 4.191%
# Epoch 420: Train Loss: 0.003369, Train MAPE: 2.575%, Val Loss: 0.012941, Val MAPE: 3.461%
# Epoch 421: Train Loss: 0.003659, Train MAPE: 2.543%, Val Loss: 0.012611, Val MAPE: 3.416%
# Epoch 422: Train Loss: 0.003495, Train MAPE: 2.994%, Val Loss: 0.015468, Val MAPE: 4.209%
# Epoch 423: Train Loss: 0.003431, Train MAPE: 3.028%, Val Loss: 0.012493, Val MAPE: 4.242%
# Epoch 424: Train Loss: 0.004951, Train MAPE: 3.244%, Val Loss: 0.014990, Val MAPE: 4.108%
# Epoch 425: Train Loss: 0.003747, Train MAPE: 2.674%, Val Loss: 0.015126, Val MAPE: 3.532%
# Epoch 426: Train Loss: 0.004500, Train MAPE: 2.922%, Val Loss: 0.014390, Val MAPE: 3.778%
# Epoch 427: Train Loss: 0.003670, Train MAPE: 2.572%, Val Loss: 0.013121, Val MAPE: 3.649%
# Epoch 428: Train Loss: 0.004044, Train MAPE: 2.872%, Val Loss: 0.013454, Val MAPE: 4.045%
# Epoch 429: Train Loss: 0.003493, Train MAPE: 2.534%, Val Loss: 0.013062, Val MAPE: 3.493%
# Epoch 430: Train Loss: 0.003768, Train MAPE: 2.759%, Val Loss: 0.012859, Val MAPE: 4.043%
# Epoch 431: Train Loss: 0.003340, Train MAPE: 2.754%, Val Loss: 0.012363, Val MAPE: 3.802%
# Epoch 432: Train Loss: 0.003686, Train MAPE: 2.966%, Val Loss: 0.012664, Val MAPE: 4.104%
# Epoch 433: Train Loss: 0.003736, Train MAPE: 3.006%, Val Loss: 0.013156, Val MAPE: 4.131%
# Epoch 434: Train Loss: 0.003779, Train MAPE: 2.810%, Val Loss: 0.012925, Val MAPE: 3.953%
# Epoch 435: Train Loss: 0.004075, Train MAPE: 2.539%, Val Loss: 0.014622, Val MAPE: 3.639%
# Epoch 436: Train Loss: 0.003092, Train MAPE: 2.521%, Val Loss: 0.011634, Val MAPE: 4.230%
# Epoch 437: Train Loss: 0.004075, Train MAPE: 2.724%, Val Loss: 0.013015, Val MAPE: 3.631%
# Epoch 438: Train Loss: 0.003412, Train MAPE: 2.656%, Val Loss: 0.011879, Val MAPE: 3.602%
# Epoch 439: Train Loss: 0.003232, Train MAPE: 2.468%, Val Loss: 0.013230, Val MAPE: 3.428%
# Epoch 440: Train Loss: 0.003268, Train MAPE: 2.457%, Val Loss: 0.012272, Val MAPE: 3.367%
# Epoch 441: Train Loss: 0.003612, Train MAPE: 2.650%, Val Loss: 0.013849, Val MAPE: 3.667%
# Epoch 442: Train Loss: 0.003394, Train MAPE: 2.664%, Val Loss: 0.013028, Val MAPE: 3.711%
# Epoch 443: Train Loss: 0.003288, Train MAPE: 2.577%, Val Loss: 0.012567, Val MAPE: 3.510%
# Epoch 444: Train Loss: 0.004476, Train MAPE: 2.633%, Val Loss: 0.014107, Val MAPE: 3.633%
# Epoch 445: Train Loss: 0.003486, Train MAPE: 2.638%, Val Loss: 0.012909, Val MAPE: 3.497%
# Epoch 446: Train Loss: 0.003201, Train MAPE: 2.613%, Val Loss: 0.012573, Val MAPE: 3.522%
# Epoch 447: Train Loss: 0.003955, Train MAPE: 2.621%, Val Loss: 0.014056, Val MAPE: 3.553%
# Epoch 448: Train Loss: 0.003344, Train MAPE: 2.570%, Val Loss: 0.012695, Val MAPE: 3.379%
# Epoch 449: Train Loss: 0.003776, Train MAPE: 2.801%, Val Loss: 0.012962, Val MAPE: 3.733%
# Epoch 450: Train Loss: 0.003032, Train MAPE: 2.730%, Val Loss: 0.013157, Val MAPE: 3.875%
# Epoch 451: Train Loss: 0.003075, Train MAPE: 2.769%, Val Loss: 0.012103, Val MAPE: 3.893%
# Epoch 452: Train Loss: 0.003914, Train MAPE: 2.843%, Val Loss: 0.012595, Val MAPE: 3.836%
# Epoch 453: Train Loss: 0.003321, Train MAPE: 2.571%, Val Loss: 0.013724, Val MAPE: 3.561%
# Epoch 454: Train Loss: 0.003159, Train MAPE: 2.511%, Val Loss: 0.013859, Val MAPE: 3.433%
# Epoch 455: Train Loss: 0.003223, Train MAPE: 2.719%, Val Loss: 0.013056, Val MAPE: 3.847%
# Epoch 456: Train Loss: 0.002924, Train MAPE: 2.789%, Val Loss: 0.012418, Val MAPE: 3.780%
# Epoch 457: Train Loss: 0.004783, Train MAPE: 3.235%, Val Loss: 0.014240, Val MAPE: 4.000%
# Epoch 458: Train Loss: 0.003102, Train MAPE: 2.626%, Val Loss: 0.013211, Val MAPE: 3.722%
# Epoch 459: Train Loss: 0.004270, Train MAPE: 2.814%, Val Loss: 0.013569, Val MAPE: 3.966%
# Epoch 460: Train Loss: 0.003748, Train MAPE: 2.517%, Val Loss: 0.013273, Val MAPE: 3.516%
# Epoch 461: Train Loss: 0.003138, Train MAPE: 2.704%, Val Loss: 0.012907, Val MAPE: 3.827%
# Epoch 462: Train Loss: 0.002908, Train MAPE: 2.796%, Val Loss: 0.011911, Val MAPE: 3.873%
# Epoch 463: Train Loss: 0.003000, Train MAPE: 2.732%, Val Loss: 0.012575, Val MAPE: 3.915%
# Epoch 464: Train Loss: 0.003239, Train MAPE: 2.601%, Val Loss: 0.012361, Val MAPE: 3.732%
# Epoch 465: Train Loss: 0.003208, Train MAPE: 2.581%, Val Loss: 0.012241, Val MAPE: 3.681%
# Epoch 466: Train Loss: 0.005223, Train MAPE: 2.488%, Val Loss: 0.015980, Val MAPE: 3.570%
# Epoch 467: Train Loss: 0.003010, Train MAPE: 2.460%, Val Loss: 0.011909, Val MAPE: 3.550%
# Epoch 468: Train Loss: 0.002797, Train MAPE: 2.428%, Val Loss: 0.036638, Val MAPE: 3.739%
# Epoch 469: Train Loss: 0.003292, Train MAPE: 2.593%, Val Loss: 0.012718, Val MAPE: 3.660%
# Epoch 470: Train Loss: 0.003733, Train MAPE: 2.813%, Val Loss: 0.013534, Val MAPE: 3.874%
# Epoch 471: Train Loss: 0.003099, Train MAPE: 2.526%, Val Loss: 0.012141, Val MAPE: 3.807%
# Epoch 472: Train Loss: 0.002795, Train MAPE: 2.476%, Val Loss: 0.012424, Val MAPE: 3.758%
# Epoch 473: Train Loss: 0.004279, Train MAPE: 2.953%, Val Loss: 0.013224, Val MAPE: 3.999%
# Epoch 474: Train Loss: 0.003591, Train MAPE: 2.580%, Val Loss: 0.013474, Val MAPE: 3.711%
# Epoch 475: Train Loss: 0.004169, Train MAPE: 2.670%, Val Loss: 0.013356, Val MAPE: 4.044%
# Epoch 476: Train Loss: 0.003426, Train MAPE: 2.692%, Val Loss: 0.011872, Val MAPE: 3.917%
# Epoch 477: Train Loss: 0.003083, Train MAPE: 2.967%, Val Loss: 0.012435, Val MAPE: 4.070%
# Epoch 478: Train Loss: 0.003431, Train MAPE: 2.463%, Val Loss: 0.013626, Val MAPE: 3.573%
# Epoch 479: Train Loss: 0.003304, Train MAPE: 2.661%, Val Loss: 0.013048, Val MAPE: 3.750%
# Epoch 480: Train Loss: 0.002971, Train MAPE: 2.579%, Val Loss: 0.012628, Val MAPE: 3.925%
# Epoch 481: Train Loss: 0.003249, Train MAPE: 2.805%, Val Loss: 0.013236, Val MAPE: 3.851%
# Epoch 482: Train Loss: 0.004071, Train MAPE: 2.683%, Val Loss: 0.014802, Val MAPE: 3.646%
# Epoch 483: Train Loss: 0.002822, Train MAPE: 2.445%, Val Loss: 0.012448, Val MAPE: 3.458%
# Epoch 484: Train Loss: 0.003316, Train MAPE: 2.819%, Val Loss: 0.013778, Val MAPE: 3.848%
# Epoch 485: Train Loss: 0.003108, Train MAPE: 2.977%, Val Loss: 0.011246, Val MAPE: 4.384%
# Epoch 486: Train Loss: 0.003995, Train MAPE: 2.902%, Val Loss: 0.013313, Val MAPE: 4.012%
# Epoch 487: Train Loss: 0.002945, Train MAPE: 2.714%, Val Loss: 0.012320, Val MAPE: 3.901%
# Epoch 488: Train Loss: 0.003156, Train MAPE: 2.512%, Val Loss: 0.013956, Val MAPE: 3.487%
# Epoch 489: Train Loss: 0.002754, Train MAPE: 2.751%, Val Loss: 0.013586, Val MAPE: 3.932%
# Epoch 490: Train Loss: 0.003694, Train MAPE: 2.771%, Val Loss: 0.013263, Val MAPE: 3.954%
# Epoch 491: Train Loss: 0.003625, Train MAPE: 2.604%, Val Loss: 0.013870, Val MAPE: 4.156%
# Epoch 492: Train Loss: 0.002997, Train MAPE: 2.486%, Val Loss: 0.012260, Val MAPE: 3.576%
# Epoch 493: Train Loss: 0.002923, Train MAPE: 2.686%, Val Loss: 0.013141, Val MAPE: 3.820%
# Epoch 494: Train Loss: 0.003459, Train MAPE: 2.359%, Val Loss: 0.013784, Val MAPE: 3.475%
# Epoch 495: Train Loss: 0.002860, Train MAPE: 2.464%, Val Loss: 0.011552, Val MAPE: 3.637%
# Epoch 496: Train Loss: 0.002810, Train MAPE: 2.722%, Val Loss: 0.035604, Val MAPE: 4.068%
# Epoch 497: Train Loss: 0.002749, Train MAPE: 2.455%, Val Loss: 0.011928, Val MAPE: 3.909%
# Epoch 498: Train Loss: 0.003124, Train MAPE: 2.438%, Val Loss: 0.013661, Val MAPE: 3.579%
# Epoch 499: Train Loss: 0.003197, Train MAPE: 2.575%, Val Loss: 0.013686, Val MAPE: 3.653%
# Epoch 500: Train Loss: 0.004038, Train MAPE: 3.025%, Val Loss: 0.013227, Val MAPE: 4.196%
# Epoch 501: Train Loss: 0.002885, Train MAPE: 2.472%, Val Loss: 0.012712, Val MAPE: 3.878%
# Epoch 502: Train Loss: 0.003422, Train MAPE: 2.701%, Val Loss: 0.012411, Val MAPE: 3.845%
# Epoch 503: Train Loss: 0.002835, Train MAPE: 2.532%, Val Loss: 0.012741, Val MAPE: 4.095%
# Epoch 504: Train Loss: 0.002945, Train MAPE: 2.439%, Val Loss: 0.013297, Val MAPE: 3.940%
# Epoch 505: Train Loss: 0.003476, Train MAPE: 2.497%, Val Loss: 0.013678, Val MAPE: 3.691%
# Epoch 506: Train Loss: 0.002668, Train MAPE: 2.649%, Val Loss: 0.012193, Val MAPE: 3.763%
# Epoch 507: Train Loss: 0.002764, Train MAPE: 2.469%, Val Loss: 0.012579, Val MAPE: 3.452%
# Epoch 508: Train Loss: 0.002809, Train MAPE: 2.800%, Val Loss: 0.014522, Val MAPE: 4.125%
# Epoch 509: Train Loss: 0.003043, Train MAPE: 2.452%, Val Loss: 0.011612, Val MAPE: 3.430%
# Epoch 510: Train Loss: 0.002920, Train MAPE: 2.593%, Val Loss: 0.012469, Val MAPE: 3.682%
# Epoch 511: Train Loss: 0.003309, Train MAPE: 2.562%, Val Loss: 0.012136, Val MAPE: 3.751%
# Epoch 512: Train Loss: 0.003054, Train MAPE: 2.622%, Val Loss: 0.013740, Val MAPE: 3.604%
# Epoch 513: Train Loss: 0.002480, Train MAPE: 2.364%, Val Loss: 0.012372, Val MAPE: 3.557%
# Epoch 514: Train Loss: 0.002749, Train MAPE: 2.414%, Val Loss: 0.012086, Val MAPE: 3.433%
# Epoch 515: Train Loss: 0.002967, Train MAPE: 2.689%, Val Loss: 0.012592, Val MAPE: 3.809%
# Epoch 516: Train Loss: 0.002669, Train MAPE: 2.735%, Val Loss: 0.011690, Val MAPE: 3.875%
# Epoch 517: Train Loss: 0.003144, Train MAPE: 2.763%, Val Loss: 0.012674, Val MAPE: 4.188%
# Epoch 518: Train Loss: 0.002918, Train MAPE: 2.651%, Val Loss: 0.012909, Val MAPE: 3.809%
# Epoch 519: Train Loss: 0.002809, Train MAPE: 2.710%, Val Loss: 0.012449, Val MAPE: 4.038%
# Epoch 520: Train Loss: 0.002548, Train MAPE: 2.324%, Val Loss: 0.011384, Val MAPE: 3.449%
# Epoch 521: Train Loss: 0.003558, Train MAPE: 2.843%, Val Loss: 0.011584, Val MAPE: 3.941%
# Epoch 522: Train Loss: 0.002616, Train MAPE: 2.334%, Val Loss: 0.012224, Val MAPE: 3.399%
# Epoch 523: Train Loss: 0.002987, Train MAPE: 2.776%, Val Loss: 0.012191, Val MAPE: 4.115%
# Epoch 524: Train Loss: 0.003442, Train MAPE: 2.655%, Val Loss: 0.012715, Val MAPE: 3.687%
# Epoch 525: Train Loss: 0.003071, Train MAPE: 2.836%, Val Loss: 0.012293, Val MAPE: 3.900%
# Epoch 526: Train Loss: 0.003181, Train MAPE: 2.491%, Val Loss: 0.012606, Val MAPE: 3.425%
# Epoch 527: Train Loss: 0.002674, Train MAPE: 2.645%, Val Loss: 0.015369, Val MAPE: 3.866%
# Epoch 528: Train Loss: 0.002761, Train MAPE: 2.410%, Val Loss: 0.012209, Val MAPE: 3.499%
# Epoch 529: Train Loss: 0.002965, Train MAPE: 2.497%, Val Loss: 0.011954, Val MAPE: 3.514%
# Epoch 530: Train Loss: 0.003535, Train MAPE: 2.625%, Val Loss: 0.011887, Val MAPE: 3.753%
# Epoch 531: Train Loss: 0.003195, Train MAPE: 2.905%, Val Loss: 0.011730, Val MAPE: 4.110%
# Epoch 532: Train Loss: 0.002661, Train MAPE: 2.448%, Val Loss: 0.012318, Val MAPE: 3.666%
# ...
# Epoch 825: Train Loss: 0.001596, Train MAPE: 2.426%, Val Loss: 0.011304, Val MAPE: 3.159%
# Epoch 826: Train Loss: 0.001679, Train MAPE: 2.359%, Val Loss: 0.011713, Val MAPE: 3.013%
# Epoch 827: Train Loss: 0.001722, Train MAPE: 2.196%, Val Loss: 0.011593, Val MAPE: 2.825%
# Epoch 828: Train Loss: 0.001548, Train MAPE: 2.035%, Val Loss: 0.011686, Val MAPE: 2.933%
# Epoch 829: Train Loss: 0.002453, Train MAPE: 2.274%, Val Loss: 0.012567, Val MAPE: 3.294%
# Epoch 830: Train Loss: 0.001926, Train MAPE: 2.256%, Val Loss: 0.012446, Val MAPE: 2.901%
# Epoch 831: Train Loss: 0.001479, Train MAPE: 2.179%, Val Loss: 0.010837, Val MAPE: 2.992%
# Epoch 832: Train Loss: 0.001744, Train MAPE: 2.688%, Val Loss: 0.011358, Val MAPE: 3.426%
# Epoch 833: Train Loss: 0.001846, Train MAPE: 2.124%, Val Loss: 0.011585, Val MAPE: 2.954%
# Epoch 834: Train Loss: 0.001934, Train MAPE: 2.374%, Val Loss: 0.010662, Val MAPE: 3.151%
# Epoch 835: Train Loss: 0.001740, Train MAPE: 2.251%, Val Loss: 0.011453, Val MAPE: 2.924%
# Epoch 836: Train Loss: 0.001673, Train MAPE: 2.201%, Val Loss: 0.011496, Val MAPE: 2.913%
# Epoch 837: Train Loss: 0.001589, Train MAPE: 2.246%, Val Loss: 0.010516, Val MAPE: 2.903%
# Epoch 838: Train Loss: 0.001573, Train MAPE: 2.354%, Val Loss: 0.019383, Val MAPE: 3.224%
# Epoch 839: Train Loss: 0.001538, Train MAPE: 2.072%, Val Loss: 0.011324, Val MAPE: 2.818%
# Epoch 840: Train Loss: 0.001441, Train MAPE: 2.050%, Val Loss: 0.010684, Val MAPE: 2.881%
# Epoch 841: Train Loss: 0.001494, Train MAPE: 2.033%, Val Loss: 0.011249, Val MAPE: 2.686%
# Epoch 842: Train Loss: 0.001956, Train MAPE: 2.429%, Val Loss: 0.012092, Val MAPE: 3.024%
# Epoch 843: Train Loss: 0.001933, Train MAPE: 2.333%, Val Loss: 0.011689, Val MAPE: 2.953%
# Epoch 844: Train Loss: 0.001476, Train MAPE: 2.156%, Val Loss: 0.010454, Val MAPE: 2.795%
# Epoch 845: Train Loss: 0.001529, Train MAPE: 2.138%, Val Loss: 0.011612, Val MAPE: 2.912%
# Epoch 846: Train Loss: 0.001714, Train MAPE: 2.180%, Val Loss: 0.012056, Val MAPE: 2.858%
# Epoch 847: Train Loss: 0.001605, Train MAPE: 2.172%, Val Loss: 0.012137, Val MAPE: 2.863%
# Epoch 848: Train Loss: 0.001364, Train MAPE: 2.130%, Val Loss: 0.011057, Val MAPE: 2.833%
# Epoch 849: Train Loss: 0.001601, Train MAPE: 2.684%, Val Loss: 0.011295, Val MAPE: 3.952%
# Epoch 850: Train Loss: 0.001860, Train MAPE: 2.256%, Val Loss: 0.013305, Val MAPE: 3.008%
# Epoch 851: Train Loss: 0.001603, Train MAPE: 2.174%, Val Loss: 0.011608, Val MAPE: 2.898%
# Epoch 852: Train Loss: 0.001841, Train MAPE: 2.350%, Val Loss: 0.012677, Val MAPE: 2.898%
# Epoch 853: Train Loss: 0.001638, Train MAPE: 2.172%, Val Loss: 0.011957, Val MAPE: 2.808%
# Epoch 854: Train Loss: 0.001447, Train MAPE: 2.233%, Val Loss: 0.010724, Val MAPE: 3.129%
# Epoch 855: Train Loss: 0.001718, Train MAPE: 2.554%, Val Loss: 0.011779, Val MAPE: 3.662%
# Epoch 856: Train Loss: 0.001540, Train MAPE: 2.131%, Val Loss: 0.011683, Val MAPE: 2.851%
# Epoch 857: Train Loss: 0.001605, Train MAPE: 2.433%, Val Loss: 0.012175, Val MAPE: 3.090%
# Epoch 858: Train Loss: 0.001928, Train MAPE: 2.405%, Val Loss: 0.011246, Val MAPE: 3.191%
# Epoch 859: Train Loss: 0.001634, Train MAPE: 1.948%, Val Loss: 0.011237, Val MAPE: 2.515%
# Epoch 860: Train Loss: 0.001924, Train MAPE: 2.378%, Val Loss: 0.012516, Val MAPE: 2.970%
# Epoch 861: Train Loss: 0.001820, Train MAPE: 2.147%, Val Loss: 0.011570, Val MAPE: 2.831%
# Epoch 862: Train Loss: 0.001771, Train MAPE: 2.375%, Val Loss: 0.012117, Val MAPE: 2.869%
# Epoch 863: Train Loss: 0.001400, Train MAPE: 2.150%, Val Loss: 0.010990, Val MAPE: 2.817%
# Epoch 864: Train Loss: 0.001564, Train MAPE: 2.221%, Val Loss: 0.012207, Val MAPE: 2.833%
# Epoch 865: Train Loss: 0.001444, Train MAPE: 2.312%, Val Loss: 0.010607, Val MAPE: 3.029%
# Epoch 866: Train Loss: 0.001557, Train MAPE: 2.238%, Val Loss: 0.011334, Val MAPE: 3.033%
# Epoch 867: Train Loss: 0.001667, Train MAPE: 2.123%, Val Loss: 0.012101, Val MAPE: 2.833%
# Epoch 868: Train Loss: 0.001758, Train MAPE: 2.373%, Val Loss: 0.011501, Val MAPE: 3.048%
# Epoch 869: Train Loss: 0.001798, Train MAPE: 2.513%, Val Loss: 0.011419, Val MAPE: 3.124%
# Epoch 870: Train Loss: 0.002040, Train MAPE: 2.474%, Val Loss: 0.012254, Val MAPE: 3.552%
# Epoch 871: Train Loss: 0.002058, Train MAPE: 1.960%, Val Loss: 0.011995, Val MAPE: 3.230%
# Epoch 872: Train Loss: 0.001561, Train MAPE: 2.343%, Val Loss: 0.009901, Val MAPE: 2.956%
# Epoch 873: Train Loss: 0.001438, Train MAPE: 2.111%, Val Loss: 0.010875, Val MAPE: 2.761%
# Epoch 874: Train Loss: 0.001631, Train MAPE: 2.353%, Val Loss: 0.011336, Val MAPE: 2.966%
# Epoch 875: Train Loss: 0.001785, Train MAPE: 2.279%, Val Loss: 0.010609, Val MAPE: 2.898%
# Epoch 876: Train Loss: 0.001211, Train MAPE: 2.046%, Val Loss: 0.010809, Val MAPE: 3.200%
# Epoch 877: Train Loss: 0.001465, Train MAPE: 2.195%, Val Loss: 0.010976, Val MAPE: 3.020%
# Epoch 878: Train Loss: 0.001438, Train MAPE: 2.308%, Val Loss: 0.012647, Val MAPE: 2.954%
# Epoch 879: Train Loss: 0.001280, Train MAPE: 2.276%, Val Loss: 0.010932, Val MAPE: 2.989%
# Epoch 880: Train Loss: 0.001460, Train MAPE: 2.110%, Val Loss: 0.010869, Val MAPE: 2.986%
# Epoch 881: Train Loss: 0.001379, Train MAPE: 2.043%, Val Loss: 0.010277, Val MAPE: 2.793%
# Epoch 882: Train Loss: 0.002178, Train MAPE: 2.132%, Val Loss: 0.011651, Val MAPE: 2.850%
# Epoch 883: Train Loss: 0.002378, Train MAPE: 1.995%, Val Loss: 0.012449, Val MAPE: 2.748%
# Epoch 884: Train Loss: 0.001883, Train MAPE: 2.074%, Val Loss: 0.011094, Val MAPE: 2.790%
# Epoch 885: Train Loss: 0.001507, Train MAPE: 2.644%, Val Loss: 0.010062, Val MAPE: 3.960%
# Epoch 886: Train Loss: 0.001643, Train MAPE: 2.121%, Val Loss: 0.010967, Val MAPE: 2.720%
# Epoch 887: Train Loss: 0.001929, Train MAPE: 2.475%, Val Loss: 0.010852, Val MAPE: 3.039%
# Epoch 888: Train Loss: 0.001645, Train MAPE: 1.983%, Val Loss: 0.010823, Val MAPE: 2.501%
# Epoch 889: Train Loss: 0.001430, Train MAPE: 2.141%, Val Loss: 0.011600, Val MAPE: 2.669%
# Epoch 890: Train Loss: 0.001540, Train MAPE: 2.248%, Val Loss: 0.011124, Val MAPE: 2.891%
# Epoch 891: Train Loss: 0.001727, Train MAPE: 2.451%, Val Loss: 0.010495, Val MAPE: 3.040%
# Epoch 892: Train Loss: 0.001556, Train MAPE: 2.020%, Val Loss: 0.011147, Val MAPE: 2.674%
# Epoch 893: Train Loss: 0.001547, Train MAPE: 2.129%, Val Loss: 0.010631, Val MAPE: 2.676%
# Epoch 894: Train Loss: 0.001502, Train MAPE: 2.088%, Val Loss: 0.009865, Val MAPE: 2.539%
# Epoch 895: Train Loss: 0.001981, Train MAPE: 2.162%, Val Loss: 0.011175, Val MAPE: 2.758%
# Epoch 896: Train Loss: 0.003692, Train MAPE: 2.726%, Val Loss: 0.014238, Val MAPE: 3.694%
# Epoch 897: Train Loss: 0.001301, Train MAPE: 2.078%, Val Loss: 0.010995, Val MAPE: 2.789%
# Epoch 898: Train Loss: 0.001563, Train MAPE: 2.589%, Val Loss: 0.011203, Val MAPE: 3.097%
# Epoch 899: Train Loss: 0.001606, Train MAPE: 2.074%, Val Loss: 0.010690, Val MAPE: 2.857%
# Epoch 900: Train Loss: 0.001349, Train MAPE: 2.095%, Val Loss: 0.010539, Val MAPE: 2.716%
# Epoch 901: Train Loss: 0.002396, Train MAPE: 2.473%, Val Loss: 0.010539, Val MAPE: 3.359%
# Epoch 902: Train Loss: 0.001303, Train MAPE: 2.166%, Val Loss: 0.010836, Val MAPE: 2.929%
# Epoch 903: Train Loss: 0.001427, Train MAPE: 2.120%, Val Loss: 0.010618, Val MAPE: 2.927%
# Epoch 904: Train Loss: 0.001721, Train MAPE: 2.345%, Val Loss: 0.010904, Val MAPE: 3.206%
# Epoch 905: Train Loss: 0.001665, Train MAPE: 2.103%, Val Loss: 0.010456, Val MAPE: 2.790%
# Epoch 906: Train Loss: 0.001441, Train MAPE: 2.179%, Val Loss: 0.010684, Val MAPE: 2.909%
# Epoch 907: Train Loss: 0.001565, Train MAPE: 2.184%, Val Loss: 0.010684, Val MAPE: 3.270%
# Epoch 908: Train Loss: 0.001717, Train MAPE: 2.206%, Val Loss: 0.011192, Val MAPE: 2.724%
# Epoch 909: Train Loss: 0.001508, Train MAPE: 2.217%, Val Loss: 0.011193, Val MAPE: 2.848%
# Epoch 910: Train Loss: 0.002055, Train MAPE: 2.438%, Val Loss: 0.010437, Val MAPE: 2.904%
# Epoch 911: Train Loss: 0.001886, Train MAPE: 2.096%, Val Loss: 0.012184, Val MAPE: 2.863%
# Epoch 912: Train Loss: 0.001441, Train MAPE: 2.234%, Val Loss: 0.011166, Val MAPE: 3.037%
# Epoch 913: Train Loss: 0.001918, Train MAPE: 2.132%, Val Loss: 0.012036, Val MAPE: 2.890%
# Epoch 914: Train Loss: 0.002406, Train MAPE: 2.464%, Val Loss: 0.012464, Val MAPE: 2.952%
# Epoch 915: Train Loss: 0.001808, Train MAPE: 2.239%, Val Loss: 0.011823, Val MAPE: 2.997%
# Epoch 916: Train Loss: 0.001901, Train MAPE: 2.473%, Val Loss: 0.012055, Val MAPE: 3.018%
# Epoch 917: Train Loss: 0.001462, Train MAPE: 2.094%, Val Loss: 0.011193, Val MAPE: 2.750%
# Epoch 918: Train Loss: 0.002909, Train MAPE: 2.367%, Val Loss: 0.012376, Val MAPE: 3.002%
# Epoch 919: Train Loss: 0.001638, Train MAPE: 2.170%, Val Loss: 0.010638, Val MAPE: 2.827%
# Epoch 920: Train Loss: 0.001544, Train MAPE: 2.261%, Val Loss: 0.010635, Val MAPE: 3.026%
# Epoch 921: Train Loss: 0.001416, Train MAPE: 2.115%, Val Loss: 0.010320, Val MAPE: 3.072%
# Epoch 922: Train Loss: 0.001427, Train MAPE: 2.104%, Val Loss: 0.010898, Val MAPE: 2.809%
# Epoch 923: Train Loss: 0.001595, Train MAPE: 2.095%, Val Loss: 0.011657, Val MAPE: 2.974%
# Epoch 924: Train Loss: 0.001502, Train MAPE: 2.301%, Val Loss: 0.011106, Val MAPE: 3.115%
# Epoch 925: Train Loss: 0.001341, Train MAPE: 2.237%, Val Loss: 0.010487, Val MAPE: 2.827%
# Epoch 926: Train Loss: 0.001984, Train MAPE: 2.638%, Val Loss: 0.011529, Val MAPE: 3.161%
# Epoch 927: Train Loss: 0.001474, Train MAPE: 2.056%, Val Loss: 0.011438, Val MAPE: 2.580%
# Epoch 928: Train Loss: 0.001944, Train MAPE: 2.174%, Val Loss: 0.013464, Val MAPE: 2.743%
# Epoch 929: Train Loss: 0.001236, Train MAPE: 1.860%, Val Loss: 0.010221, Val MAPE: 2.467%
# Epoch 930: Train Loss: 0.001414, Train MAPE: 2.051%, Val Loss: 0.010970, Val MAPE: 2.618%
# Epoch 931: Train Loss: 0.001567, Train MAPE: 2.104%, Val Loss: 0.010845, Val MAPE: 2.757%
# Epoch 932: Train Loss: 0.001771, Train MAPE: 2.160%, Val Loss: 0.011259, Val MAPE: 2.811%
# Epoch 933: Train Loss: 0.001363, Train MAPE: 2.038%, Val Loss: 0.010923, Val MAPE: 2.614%
# Epoch 934: Train Loss: 0.001138, Train MAPE: 1.953%, Val Loss: 0.010237, Val MAPE: 2.730%
# Epoch 935: Train Loss: 0.001244, Train MAPE: 1.912%, Val Loss: 0.010689, Val MAPE: 2.688%
# Epoch 936: Train Loss: 0.001333, Train MAPE: 2.027%, Val Loss: 0.010724, Val MAPE: 2.679%
# Epoch 937: Train Loss: 0.001275, Train MAPE: 2.103%, Val Loss: 0.010774, Val MAPE: 2.722%
# Epoch 938: Train Loss: 0.001425, Train MAPE: 2.129%, Val Loss: 0.011056, Val MAPE: 2.752%
# Epoch 939: Train Loss: 0.001880, Train MAPE: 2.139%, Val Loss: 0.011291, Val MAPE: 2.816%
# Epoch 940: Train Loss: 0.001478, Train MAPE: 2.254%, Val Loss: 0.011855, Val MAPE: 2.793%
# Epoch 941: Train Loss: 0.001516, Train MAPE: 2.165%, Val Loss: 0.011839, Val MAPE: 2.895%
# Epoch 942: Train Loss: 0.001273, Train MAPE: 2.073%, Val Loss: 0.010394, Val MAPE: 2.843%
# Epoch 943: Train Loss: 0.001600, Train MAPE: 2.007%, Val Loss: 0.010778, Val MAPE: 2.537%
# Epoch 944: Train Loss: 0.001801, Train MAPE: 2.273%, Val Loss: 0.011384, Val MAPE: 2.800%
# Epoch 945: Train Loss: 0.001493, Train MAPE: 1.939%, Val Loss: 0.011835, Val MAPE: 2.578%
# Epoch 946: Train Loss: 0.001380, Train MAPE: 2.120%, Val Loss: 0.011481, Val MAPE: 2.622%
# Epoch 947: Train Loss: 0.001516, Train MAPE: 2.470%, Val Loss: 0.011095, Val MAPE: 3.009%
# Epoch 948: Train Loss: 0.002146, Train MAPE: 2.322%, Val Loss: 0.010447, Val MAPE: 3.336%
# Epoch 949: Train Loss: 0.001719, Train MAPE: 2.374%, Val Loss: 0.011116, Val MAPE: 3.029%
# Epoch 950: Train Loss: 0.001345, Train MAPE: 2.021%, Val Loss: 0.011011, Val MAPE: 2.705%
# Epoch 951: Train Loss: 0.001675, Train MAPE: 2.183%, Val Loss: 0.033061, Val MAPE: 2.826%
# Epoch 952: Train Loss: 0.001287, Train MAPE: 2.172%, Val Loss: 0.011373, Val MAPE: 2.705%
# Epoch 953: Train Loss: 0.001279, Train MAPE: 1.980%, Val Loss: 0.011426, Val MAPE: 2.629%
# Epoch 954: Train Loss: 0.002301, Train MAPE: 2.211%, Val Loss: 0.011424, Val MAPE: 2.871%
# Epoch 955: Train Loss: 0.001490, Train MAPE: 2.140%, Val Loss: 0.010685, Val MAPE: 2.693%
# Epoch 956: Train Loss: 0.001512, Train MAPE: 2.315%, Val Loss: 0.011399, Val MAPE: 2.840%
# Epoch 957: Train Loss: 0.001723, Train MAPE: 2.053%, Val Loss: 0.011637, Val MAPE: 2.801%
# Epoch 958: Train Loss: 0.001537, Train MAPE: 2.052%, Val Loss: 0.010567, Val MAPE: 2.724%
# Epoch 959: Train Loss: 0.001532, Train MAPE: 2.264%, Val Loss: 0.011254, Val MAPE: 2.884%
# Epoch 960: Train Loss: 0.001750, Train MAPE: 2.453%, Val Loss: 0.010585, Val MAPE: 3.111%
# Epoch 961: Train Loss: 0.001866, Train MAPE: 2.197%, Val Loss: 0.011898, Val MAPE: 2.738%
# Epoch 962: Train Loss: 0.001629, Train MAPE: 2.243%, Val Loss: 0.011106, Val MAPE: 3.010%
# Epoch 963: Train Loss: 0.002156, Train MAPE: 2.304%, Val Loss: 0.011634, Val MAPE: 2.846%
# Epoch 964: Train Loss: 0.001703, Train MAPE: 2.096%, Val Loss: 0.012228, Val MAPE: 2.669%
# Epoch 965: Train Loss: 0.001333, Train MAPE: 2.103%, Val Loss: 0.011648, Val MAPE: 3.451%
# Epoch 966: Train Loss: 0.001572, Train MAPE: 2.173%, Val Loss: 0.011909, Val MAPE: 2.836%
# Epoch 967: Train Loss: 0.001357, Train MAPE: 1.961%, Val Loss: 0.010966, Val MAPE: 2.559%
# Epoch 968: Train Loss: 0.001501, Train MAPE: 2.086%, Val Loss: 0.011154, Val MAPE: 2.638%
# Epoch 969: Train Loss: 0.001599, Train MAPE: 2.157%, Val Loss: 0.011294, Val MAPE: 2.890%
# Epoch 970: Train Loss: 0.001551, Train MAPE: 2.039%, Val Loss: 0.010939, Val MAPE: 2.682%
# Epoch 971: Train Loss: 0.001553, Train MAPE: 2.079%, Val Loss: 0.011778, Val MAPE: 2.592%
# Epoch 972: Train Loss: 0.001373, Train MAPE: 2.212%, Val Loss: 0.011149, Val MAPE: 2.805%
# Epoch 973: Train Loss: 0.001513, Train MAPE: 2.216%, Val Loss: 0.011960, Val MAPE: 3.120%
# Epoch 974: Train Loss: 0.001755, Train MAPE: 1.950%, Val Loss: 0.011929, Val MAPE: 3.301%
# Epoch 975: Train Loss: 0.001515, Train MAPE: 1.986%, Val Loss: 0.011487, Val MAPE: 2.697%
# Epoch 976: Train Loss: 0.001274, Train MAPE: 1.962%, Val Loss: 0.011276, Val MAPE: 2.797%
# Epoch 977: Train Loss: 0.001322, Train MAPE: 2.007%, Val Loss: 0.011265, Val MAPE: 2.611%
# Epoch 978: Train Loss: 0.001368, Train MAPE: 2.086%, Val Loss: 0.010699, Val MAPE: 2.735%
# Epoch 979: Train Loss: 0.001467, Train MAPE: 2.371%, Val Loss: 0.010530, Val MAPE: 3.056%
# Epoch 980: Train Loss: 0.001432, Train MAPE: 2.000%, Val Loss: 0.011187, Val MAPE: 2.747%
# Epoch 981: Train Loss: 0.001261, Train MAPE: 1.950%, Val Loss: 0.010985, Val MAPE: 2.534%
# Epoch 982: Train Loss: 0.001884, Train MAPE: 2.374%, Val Loss: 0.012621, Val MAPE: 2.995%
# Epoch 983: Train Loss: 0.001295, Train MAPE: 2.096%, Val Loss: 0.010135, Val MAPE: 2.736%
# Epoch 984: Train Loss: 0.001730, Train MAPE: 1.966%, Val Loss: 0.011725, Val MAPE: 2.622%
# Epoch 985: Train Loss: 0.001322, Train MAPE: 2.092%, Val Loss: 0.011374, Val MAPE: 2.790%
# Epoch 986: Train Loss: 0.001885, Train MAPE: 2.364%, Val Loss: 0.011555, Val MAPE: 3.062%
# Epoch 987: Train Loss: 0.001345, Train MAPE: 2.106%, Val Loss: 0.011292, Val MAPE: 2.749%
# Epoch 988: Train Loss: 0.001863, Train MAPE: 2.072%, Val Loss: 0.011751, Val MAPE: 2.629%
# Epoch 989: Train Loss: 0.001500, Train MAPE: 2.076%, Val Loss: 0.011922, Val MAPE: 2.637%
# Epoch 990: Train Loss: 0.001276, Train MAPE: 2.019%, Val Loss: 0.011520, Val MAPE: 2.538%
# Epoch 991: Train Loss: 0.001792, Train MAPE: 1.947%, Val Loss: 0.011043, Val MAPE: 2.490%
# Epoch 992: Train Loss: 0.001273, Train MAPE: 2.026%, Val Loss: 0.012159, Val MAPE: 2.720%
# Epoch 993: Train Loss: 0.001511, Train MAPE: 2.207%, Val Loss: 0.010842, Val MAPE: 3.724%
# Epoch 994: Train Loss: 0.001349, Train MAPE: 2.050%, Val Loss: 0.010940, Val MAPE: 2.583%
# Epoch 995: Train Loss: 0.001717, Train MAPE: 2.136%, Val Loss: 0.011233, Val MAPE: 2.891%
# Epoch 996: Train Loss: 0.001377, Train MAPE: 1.994%, Val Loss: 0.011389, Val MAPE: 2.601%
# Epoch 997: Train Loss: 0.001728, Train MAPE: 2.157%, Val Loss: 0.011538, Val MAPE: 2.878%
# Epoch 998: Train Loss: 0.002363, Train MAPE: 2.537%, Val Loss: 0.011653, Val MAPE: 3.167%
# Epoch 999: Train Loss: 0.001465, Train MAPE: 2.058%, Val Loss: 0.010780, Val MAPE: 2.754%
# Epoch 1000: Train Loss: 0.001228, Train MAPE: 2.042%, Val Loss: 0.010768, Val MAPE: 2.705%
#
# Lowest Train Loss: 1.860342 at Epoch 929
# Lowest Val Loss: 2.466925 at Epoch 929

# %% [markdown]
# ### Sample from the model

# %%
def sample_from_model(model, input, sequence_length, fixed_features_len, device):
    model.eval()

    input = input[:fixed_features_len, :]
    T, C = input.shape
    input = input.view(1, T, C)
    outputs = torch.zeros(sequence_length, 2, device=device)
    
    with torch.no_grad():
    
        for i in range(0, sequence_length):
            output = model(input)
            predictions = output[:, -1, :].view(1, 1, 2)
            outputs[i, :] = predictions
            
            if i == sequence_length:
                break

            input = torch.cat((input, predictions), dim=1)

    return outputs

# %%
def calculate_mape(true_values, predictions, epsilon=1e-8):
    mape = torch.mean(torch.abs((true_values - predictions) / (true_values + epsilon))) * 100
    return mape.item()

# %%
def autoregressive_error(model, loader, n_samples, sequence_length, fixed_features_len, use_scaling):

    mapes = []
    
    for idx in range(n_samples):
        input = loader.dataset[idx][0]
        
        outputs = sample_from_model(model, input, sequence_length, fixed_features_len, device)
        targets = loader.dataset[idx][1][fixed_features_len-1:, :]

        T, C = outputs.shape
        outputs = outputs.view(1, T, C)
        targets = targets.view(1, T, C)
        
        if use_scaling:
            outputs = torch.tensor(reverse_tranform_output(outputs, 0, label_scaler))
            targets = torch.tensor(reverse_tranform_output(targets, 0, label_scaler))
        
        mapes.append(calculate_mape(targets, outputs))

    return np.mean(mapes)

# %%
n_samples = 100
sequence_length = 27
fixed_features_len = len(fixed_features)
loader = train_loader

autoregressive_error(model, loader, n_samples, sequence_length, fixed_features_len, use_scaling)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[185], line 6
#       3 fixed_features_len = len(fixed_features)
#       4 loader = train_loader
# ----> 6 autoregressive_error(model, loader, n_samples, sequence_length, fixed_features_len, use_scaling)
#
# Cell In[184], line 8, in autoregressive_error(model, loader, n_samples, sequence_length, fixed_features_len, use_scaling)
#       5 for idx in range(n_samples):
#       6     input = loader.dataset[idx][0]
# ----> 8     outputs = sample_from_model(model, input, sequence_length, fixed_features_len, device)
#       9     targets = loader.dataset[idx][1][fixed_features_len-1:, :]
#      11     T, C = outputs.shape
#
# Cell In[182], line 13, in sample_from_model(model, input, sequence_length, fixed_features_len, device)
#      11 for i in range(0, sequence_length):
#      12     output = model(input)
# ---> 13     predictions = output[:, -1, :].view(1, 1, 2)
#      14     outputs[i, :] = predictions
#      16     if i == sequence_length:
#
# RuntimeError: shape '[1, 1, 2]' is invalid for input of size 54

# %%
n_samples = 1000
sequence_length = 27
fixed_features_len = len(fixed_features)
max_features = fixed_features_len + len(labels) - 2

total_mapes = []

for j in range(sequence_length):
    fixed_labels_len = j
    
    mapes = []
    
    for idx in range(n_samples):
        input = val_loader.dataset[idx][0][fixed_labels_len]
        output = sample_from_model(model, input, sequence_length, fixed_features_len, fixed_labels_len, max_features, device)
        
        target = convert(val_loader.dataset[idx][1].reshape(-1))
        output = convert(output.reshape(-1))
        
        mapes.append(calculate_mape(target, output))
    
        if (idx+1) % 1000 == 0:
            print(f"sequence {idx/1000} done")

    total_mapes.append(np.mean(mapes))

print(total_mapes)
